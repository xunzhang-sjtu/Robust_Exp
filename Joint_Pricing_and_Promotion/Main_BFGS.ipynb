# %%
using LinearAlgebra
using Distributions
using Optim
using Random
using StatsFuns
using JuMP
using MosekTools
using StatsBase
using SparseArrays # 可选，用于处理稀疏性（如果数据量很大）
using FileIO
using JLD2
using Plots
using LaTeXStrings
using DataFrames, Colors
using StatsPlots   # 提供 boxplot，基于 Plots

include("Params_PP.jl")
include("Data_Generation_PP.jl")
include("Estimation_PP.jl")
include("Evaluation_PP.jl")
# # include("Plot_Figures.jl")
include("Implement_All_Methods_PP.jl")
include("Models_PP.jl")
# Out:
# Solve_RO (generic function with 1 method)

# %% [markdown]
# ## Functions

# %%
function Generate_Input_this(S_train, N, N_u, K, offdiag_sign,max_offdiag,P_bar,is_original_setting,lambda)
    Input_Data_this = Dict()
    A_true, B_true = Generate_Coef(N_u, N, max_offdiag, offdiag_sign,is_original_setting);
    P_train,PM_train,choice_train,PM_train_extend = Generate_Data(N,S_train,A_true,B_true,P_bar);

    Input_Data_this["A_true"] = A_true;
    Input_Data_this["B_true"] = B_true;
    Input_Data_this["P_dag"] = round.(rand(N, K) .* P_bar; digits=2);
    Input_Data_this["P_train"] = P_train;
    Input_Data_this["PM_train_extend"] = PM_train_extend;
    Input_Data_this["choice_train"] = choice_train;

    # A_hat,B_hat = Estimate_MNL_Para(PM_train_extend, P_train, choice_train,S_train, N);

    # A_hat,B_hat = Estimate_MNL_Para_Ridge(PM_train_extend, P_train, choice_train,S_train, N, lambda);
    A_hat,B_hat,Intercept,obj_val,sol_status,solve_time = Estimate_OPT_Model(N,N_u*N,S_train,PM_train,P_train,choice_train,false,0.0001)
    A_hat = hcat(A_hat, reshape(Intercept, :,1))

    Input_Data_this["A_hat"] = A_hat
    Input_Data_this["B_hat"] = B_hat
    return Input_Data_this
end
# Out:
# Generate_Input_this (generic function with 1 method)

# %%
function Get_Input_Data(Input_Data_this)
    A_true = Input_Data_this["A_true"]
    B_true = Input_Data_this["B_true"]
    P_dag = Input_Data_this["P_dag"]
    P_train = Input_Data_this["P_train"]
    PM_train_extend = Input_Data_this["PM_train_extend"]
    choice_train = Input_Data_this["choice_train"]
    A_hat = Input_Data_this["A_hat"]
    B_hat = Input_Data_this["B_hat"]
    return A_true,B_true,P_dag,P_train,PM_train_extend,choice_train,A_hat,B_hat
end
# Out:
# Get_Input_Data (generic function with 1 method)

# %%
function solve_ETO_this(N,N_u,K,A,B,A_true, B_true,P_dag,Time_Limit)
    RST_this = Dict()
    status_this = "NotDefined"
    obj_,X_,Promo_, time_,status_ = Solve_ETO(N,N_u,K,A, B,P_dag,Time_Limit)
    if status_ != "OPTIMAL"
        status_this = status_
    else
        status_this = status_
        rev_, price_ = compute_oof(X_, A_true, B_true, vcat(Promo_,1), P_dag)
        RST_this["obj"] = obj_
        RST_this["price"] = price_
        RST_this["promo"] = Promo_
        RST_this["time"] = time_
        RST_this["Rev"] = rev_
        RST_this["status"] = status_
    end
    return RST_this,status_this
end
# Out:
# solve_ETO_this (generic function with 1 method)

# %%
function solve_RO_this(N,N_u,K,A_hat,B_hat,A_true, B_true,P_dag,psi_lb,psi_ub,phi_lb,phi_ub,gamma_list,dual_norm,Time_Limit)
    RST_this = Dict()
    status_this = "NotDefined"
    for gamma in gamma_list
        obj_RO,X_RO,Promo_RO, time_RO,status_RO = Solve_RO(N,N_u,K,A_hat,B_hat,P_dag,psi_lb,psi_ub,phi_lb,phi_ub,gamma * ones(N),dual_norm,Time_Limit)
        println("gamma=$(gamma),status:",status_RO,",time=$time_RO")
        if status_RO != "OPTIMAL"
            status_this = status_RO
            break
        else
            status_this = status_RO
            rev_RO, price_RO = compute_oof(X_RO, A_true, B_true, vcat(Promo_RO,1), P_dag)
            RST_this["obj_gamma=$(gamma)"] = obj_RO
            RST_this["price_gamma=$(gamma)"] = price_RO
            RST_this["promo_gamma=$(gamma)"] = Promo_RO
            RST_this["time_gamma=$(gamma)"] = time_RO
            RST_this["Rev_gamma=$(gamma)"] = rev_RO
            RST_this["status"] = status_this
        end
    end
    return RST_this,status_this
end
# Out:
# solve_RO_this (generic function with 1 method)

# %% [markdown]
# #### Parameters

# %%
Params = get_default_params_PP()
seed = Params["seed"]
N = Params["N"]
N_u = Params["N_u"] 
K = Params["K"] 
S_train = Params["S_train"]
S_test = Params["S_test"]
P_bar = Params["P_bar"]
iterations = Params["iterations"]
offdiag_sign = Params["offdiag_sign"]
max_offdiag = Params["max_offdiag"]
Time_Limit = Params["Time_Limit"]
gamma_list = Params["gamma_list"]
dual_norm = Params["dual_norm"]
psi_lb = Params["psi_lb"]
psi_ub = Params["psi_ub"]
phi_lb = Params["phi_lb"]
phi_ub = Params["phi_ub"]
# Out:
# 3-element Vector{Float64}:
#  0.0
#  0.0
#  0.0

# %%
is_original_setting = true
Random.seed!(seed)

project_dir = "Joint_Pricing_and_Promotion/"
current_dir = pwd()
parent_dir = dirname(current_dir)
grand_pa_dir = dirname(parent_dir)
data_dir = string(dirname(grand_pa_dir), "/Data/")
if !isdir(data_dir)
    mkpath(data_dir)
end
if is_original_setting
    sub_file_name = "MS_2024_N=$(N)_N_u=$(N_u)_K=$(K)_S_train=$(S_train)_seed=$(seed)_ECP_Estimation/"
else
    sub_file_name = "N=$(N)_N_u=$(N_u)_K=$(K)_S_train=$(S_train)_offdiag_sign=$(offdiag_sign)_max_offdiag=$(max_offdiag)_seed=$(seed)_Ridge/"
end
this_data_file = string(data_dir,project_dir,sub_file_name)
if !isdir(this_data_file)
    mkpath(this_data_file)
end
println(this_data_file)
save(string(this_data_file, "Params.jld2"), Params);
# Out:
# /Users/zhangxun/Dropbox/Research/Robust_Exp/Data/Joint_Pricing_and_Promotion/MS_2024_N=3_N_u=1_K=30_S_train=100_seed=3_ECP_Estimation/

# %%
lambda = 0.1
Result_All = Dict()
iter = 1
while iter <= iterations
    t_start = time()  # 记录开始时间
    Input_Data_this = Generate_Input_this(S_train, N, N_u, K, offdiag_sign,max_offdiag,P_bar,is_original_setting,lambda)
    A_true,B_true,P_dag,P_train,PM_train_extend,choice_train,A_hat,B_hat = Get_Input_Data(Input_Data_this)
    if any(isnan, A_hat) || any(isnan, B_hat) || norm([vec(A_true .- A_hat);vec(B_true .- B_hat)],2) >= 10
        println("Estimate contains NaN values")
        continue
    end
    Result_All["Input_Data_iter=$(iter)"] = Input_Data_this

    RST_Oracle,status_Oracle = solve_ETO_this(N,N_u,K,A_true,B_true,A_true, B_true,P_dag,Time_Limit)
    println("Oracle: status = ",status_Oracle,",time=",RST_Oracle["time"])
    if status_Oracle != "OPTIMAL"
        println("Oracle did not approach the optimal solution")
        continue
    end
    Result_All["RST_Oracle_iter=$(iter)"] = RST_Oracle

    RST_ETO,status_ETO = solve_ETO_this(N,N_u,K,A_hat,B_hat,A_true, B_true,P_dag,Time_Limit)
    println("ETO: status = ",status_ETO,",time=",RST_ETO["time"])
    if status_ETO != "OPTIMAL"
        println("ETO did not approach the optimal solution")
        continue
    end
    Result_All["RST_ETO_iter=$(iter)"] = RST_ETO
    
    obj_RO,X_RO,Promo_RO, time_RO,status_RO = Solve_RO(N,N_u,K,A_hat,B_hat,P_dag,psi_lb,psi_ub,phi_lb,phi_ub,0.0 * ones(N),dual_norm,Time_Limit)
    if status_RO != "OPTIMAL"
        println("RO did not approach the optimal solution")
        continue
    end
    rev_RO, price_RO = compute_oof(X_RO, A_true, B_true, vcat(Promo_RO,1), P_dag)
    if abs(rev_RO - RST_ETO["Rev"]) >= 0.001
        println("ETO rev is not equivalent to RO rev")
        continue
    end

    RST_RO,status_RO = solve_RO_this(N,N_u,K,A_hat,B_hat,A_true, B_true,P_dag,psi_lb,psi_ub,phi_lb,phi_ub,gamma_list,dual_norm,Time_Limit)
    # println("RO status = ",status_RO)
    if status_RO != "OPTIMAL"
        println("RO did not approach the optimal solution")
        continue
    end
    Result_All["RST_RO_iter=$(iter)"] = RST_RO
    save(string(this_data_file, "Result_All.jld2"), Result_All);
    t_end = time()  # 记录结束时间
    println("******* Time for iter $iter: ", round(t_end - t_start, digits=2), " seconds *********")
    iter = iter + 1
end
save(string(this_data_file, "Result_All_lambda=$(lambda).jld2"), Result_All);
# Out:
# Oracle: status = OPTIMAL,time=2.652582883834839
# ETO: status = OPTIMAL,time=4.379035949707031
# gamma=0.0,status:OPTIMAL,time=48.02419996261597
# gamma=0.005,status:OPTIMAL,time=42.240352153778076
# gamma=0.01,status:OPTIMAL,time=36.7528030872345
# gamma=0.015,status:OPTIMAL,time=56.40366888046265
# gamma=0.02,status:OPTIMAL,time=47.88881015777588
# gamma=0.03,status:OPTIMAL,time=42.70000886917114
# gamma=0.04,status:OPTIMAL,time=35.63337707519531
# gamma=0.06,status:OPTIMAL,time=28.413650035858154
# gamma=0.08,status:OPTIMAL,time=29.64417290687561
# ******* Time for iter 1: 435.32 seconds *********
# Oracle: status = OPTIMAL,time=1.3993899822235107
# ETO: status = OPTIMAL,time=9.620612859725952
# ETO rev is not equivalent to RO rev
# Estimate contains NaN values
# Oracle: status = OPTIMAL,time=3.720992088317871
# ETO: status = OPTIMAL,time=6.827455997467041
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.8982789516448975
# ETO: status = OPTIMAL,time=1.7770850658416748
# gamma=0.0,status:OPTIMAL,time=8.78025197982788
# gamma=0.005,status:OPTIMAL,time=7.481133937835693
# gamma=0.01,status:OPTIMAL,time=7.899606943130493
# gamma=0.015,status:OPTIMAL,time=7.429590940475464
# gamma=0.02,status:OPTIMAL,time=10.864123106002808
# gamma=0.03,status:OPTIMAL,time=14.69152307510376
# gamma=0.04,status:OPTIMAL,time=15.833194017410278
# gamma=0.06,status:OPTIMAL,time=27.692591190338135
# gamma=0.08,status:OPTIMAL,time=22.163896083831787
# ******* Time for iter 2: 137.08 seconds *********
# Oracle: status = OPTIMAL,time=3.577552080154419
# ETO: status = OPTIMAL,time=12.129210948944092
# gamma=0.0,status:OPTIMAL,time=45.4445059299469
# gamma=0.005,status:OPTIMAL,time=49.30367994308472
# gamma=0.01,status:OPTIMAL,time=41.79716110229492
# gamma=0.015,status:OPTIMAL,time=38.548150062561035
# gamma=0.02,status:OPTIMAL,time=36.71285080909729
# gamma=0.03,status:OPTIMAL,time=34.29603600502014
# gamma=0.04,status:OPTIMAL,time=33.903167963027954
# gamma=0.06,status:OPTIMAL,time=25.27033805847168
# gamma=0.08,status:OPTIMAL,time=12.453439950942993
# ******* Time for iter 3: 381.04 seconds *********
# Oracle: status = OPTIMAL,time=1.659789800643921
# ETO: status = OPTIMAL,time=10.876708984375
# gamma=0.0,status:OPTIMAL,time=33.19585084915161
# gamma=0.005,status:OPTIMAL,time=33.72807288169861
# gamma=0.01,status:OPTIMAL,time=43.610345125198364
# gamma=0.015,status:OPTIMAL,time=53.3499698638916
# gamma=0.02,status:OPTIMAL,time=48.247644901275635
# gamma=0.03,status:OPTIMAL,time=38.4630651473999
# gamma=0.04,status:OPTIMAL,time=41.570449113845825
# gamma=0.06,status:OPTIMAL,time=31.971812963485718
# gamma=0.08,status:OPTIMAL,time=23.919883966445923
# ******* Time for iter 4: 393.92 seconds *********
# Oracle: status = OPTIMAL,time=2.7378039360046387
# ETO: status = OPTIMAL,time=2.296588897705078
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.1434409618377686
# ETO: status = OPTIMAL,time=16.88069987297058
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.7892649173736572
# ETO: status = OPTIMAL,time=23.490839958190918
# gamma=0.0,status:OPTIMAL,time=26.978621006011963
# gamma=0.005,status:OPTIMAL,time=57.79887008666992
# gamma=0.01,status:OPTIMAL,time=26.310433864593506
# gamma=0.015,status:OPTIMAL,time=24.208504915237427
# gamma=0.02,status:OPTIMAL,time=48.40934991836548
# gamma=0.03,status:OPTIMAL,time=23.683055877685547
# gamma=0.04,status:OPTIMAL,time=30.59325408935547
# gamma=0.06,status:OPTIMAL,time=18.174612045288086
# gamma=0.08,status:OPTIMAL,time=7.551503896713257
# ******* Time for iter 5: 317.36 seconds *********
# Oracle: status = OPTIMAL,time=11.16624116897583
# ETO: status = OPTIMAL,time=12.918760061264038
# gamma=0.0,status:OPTIMAL,time=18.668888092041016
# gamma=0.005,status:OPTIMAL,time=9.97967791557312
# gamma=0.01,status:OPTIMAL,time=12.79751992225647
# gamma=0.015,status:OPTIMAL,time=15.728839874267578
# gamma=0.02,status:OPTIMAL,time=35.80329918861389
# gamma=0.03,status:OPTIMAL,time=29.087697982788086
# gamma=0.04,status:OPTIMAL,time=23.04763698577881
# gamma=0.06,status:OPTIMAL,time=28.70413303375244
# gamma=0.08,status:OPTIMAL,time=26.682392835617065
# ******* Time for iter 6: 234.75 seconds *********
# Oracle: status = OPTIMAL,time=1.53090500831604
# ETO: status = OPTIMAL,time=11.857453107833862
# gamma=0.0,status:OPTIMAL,time=37.37247085571289
# gamma=0.005,status:TIME_LIMIT,time=892.1662838459015
# RO did not approach the optimal solution
# Oracle: status = OPTIMAL,time=2.6700029373168945
# ETO: status = OPTIMAL,time=11.362874031066895
# gamma=0.0,status:OPTIMAL,time=13.706138849258423
# gamma=0.005,status:OPTIMAL,time=13.309360027313232
# gamma=0.01,status:OPTIMAL,time=14.65926194190979
# gamma=0.015,status:OPTIMAL,time=11.595620155334473
# gamma=0.02,status:OPTIMAL,time=13.208627939224243
# gamma=0.03,status:OPTIMAL,time=14.433372974395752
# gamma=0.04,status:OPTIMAL,time=13.791356086730957
# gamma=0.06,status:OPTIMAL,time=11.956835985183716
# gamma=0.08,status:OPTIMAL,time=10.401560068130493
# ******* Time for iter 7: 146.36 seconds *********
# Oracle: status = OPTIMAL,time=1.2435081005096436
# ETO: status = OPTIMAL,time=10.720501899719238
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.9349009990692139
# ETO: status = OPTIMAL,time=8.56456995010376
# gamma=0.0,status:OPTIMAL,time=24.318084955215454
# gamma=0.005,status:OPTIMAL,time=27.572359085083008
# gamma=0.01,status:OPTIMAL,time=31.95412302017212
# gamma=0.015,status:OPTIMAL,time=34.243752002716064
# gamma=0.02,status:OPTIMAL,time=29.758720874786377
# gamma=0.03,status:OPTIMAL,time=37.54451894760132
# gamma=0.04,status:OPTIMAL,time=27.05729103088379
# gamma=0.06,status:OPTIMAL,time=35.45210814476013
# gamma=0.08,status:OPTIMAL,time=28.63508701324463
# ******* Time for iter 8: 311.56 seconds *********
# Oracle: status = OPTIMAL,time=2.620742082595825
# ETO: status = OPTIMAL,time=5.93196702003479
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.4520080089569092
# ETO: status = OPTIMAL,time=9.058619022369385
# gamma=0.0,status:OPTIMAL,time=12.779926061630249
# gamma=0.005,status:OPTIMAL,time=13.071306943893433
# gamma=0.01,status:OPTIMAL,time=12.77160906791687
# gamma=0.015,status:OPTIMAL,time=10.806472063064575
# gamma=0.02,status:OPTIMAL,time=9.26585602760315
# gamma=0.03,status:OPTIMAL,time=11.390483856201172
# gamma=0.04,status:OPTIMAL,time=10.574184894561768
# gamma=0.06,status:OPTIMAL,time=10.171772003173828
# gamma=0.08,status:OPTIMAL,time=14.298892974853516
# ******* Time for iter 9: 128.74 seconds *********
# Oracle: status = OPTIMAL,time=1.8339910507202148
# ETO: status = OPTIMAL,time=13.984385013580322
# gamma=0.0,status:OPTIMAL,time=19.272763967514038
# gamma=0.005,status:OPTIMAL,time=19.363494873046875
# gamma=0.01,status:OPTIMAL,time=29.596816062927246
# gamma=0.015,status:OPTIMAL,time=18.91172218322754
# gamma=0.02,status:OPTIMAL,time=15.418398141860962
# gamma=0.03,status:OPTIMAL,time=16.13720703125
# gamma=0.04,status:OPTIMAL,time=12.722458124160767
# gamma=0.06,status:OPTIMAL,time=7.985262870788574
# gamma=0.08,status:OPTIMAL,time=8.059221982955933
# ******* Time for iter 10: 182.88 seconds *********
# Oracle: status = OPTIMAL,time=2.5639848709106445
# ETO: status = OPTIMAL,time=39.776549100875854
# gamma=0.0,status:OPTIMAL,time=45.70868897438049
# gamma=0.005,status:OPTIMAL,time=36.89417099952698
# gamma=0.01,status:OPTIMAL,time=32.61322903633118
# gamma=0.015,status:OPTIMAL,time=30.47747015953064
# gamma=0.02,status:OPTIMAL,time=33.791635036468506
# gamma=0.03,status:OPTIMAL,time=31.511842012405396
# gamma=0.04,status:OPTIMAL,time=19.714468955993652
# gamma=0.06,status:OPTIMAL,time=14.869474172592163
# gamma=0.08,status:OPTIMAL,time=11.070542097091675
# ******* Time for iter 11: 344.46 seconds *********
# Oracle: status = OPTIMAL,time=1.737112045288086
# ETO: status = OPTIMAL,time=12.98967695236206
# gamma=0.0,status:OPTIMAL,time=37.13368201255798
# gamma=0.005,status:OPTIMAL,time=20.41567897796631
# gamma=0.01,status:OPTIMAL,time=28.15037202835083
# gamma=0.015,status:OPTIMAL,time=14.740318059921265
# gamma=0.02,status:OPTIMAL,time=21.928344011306763
# gamma=0.03,status:OPTIMAL,time=20.716787099838257
# gamma=0.04,status:OPTIMAL,time=21.99627184867859
# gamma=0.06,status:OPTIMAL,time=19.641370058059692
# gamma=0.08,status:OPTIMAL,time=16.404217004776
# ******* Time for iter 12: 253.12 seconds *********
# Oracle: status = OPTIMAL,time=1.482254981994629
# ETO: status = OPTIMAL,time=14.099356889724731
# gamma=0.0,status:OPTIMAL,time=25.00917887687683
# gamma=0.005,status:OPTIMAL,time=44.075011014938354
# gamma=0.01,status:OPTIMAL,time=49.46026301383972
# gamma=0.015,status:OPTIMAL,time=30.62214684486389
# gamma=0.02,status:OPTIMAL,time=32.487385988235474
# gamma=0.03,status:OPTIMAL,time=28.963696002960205
# gamma=0.04,status:OPTIMAL,time=32.98415398597717
# gamma=0.06,status:OPTIMAL,time=16.042582035064697
# gamma=0.08,status:OPTIMAL,time=13.966207027435303
# ******* Time for iter 13: 314.35 seconds *********
# Oracle: status = OPTIMAL,time=3.1863551139831543
# ETO: status = OPTIMAL,time=9.572949886322021
# gamma=0.0,status:OPTIMAL,time=41.912750005722046
# gamma=0.005,status:OPTIMAL,time=38.94745492935181
# gamma=0.01,status:OPTIMAL,time=36.88861322402954
# gamma=0.015,status:OPTIMAL,time=50.13474798202515
# gamma=0.02,status:OPTIMAL,time=57.13009691238403
# gamma=0.03,status:OPTIMAL,time=41.75496292114258
# gamma=0.04,status:OPTIMAL,time=17.783436059951782
# gamma=0.06,status:OPTIMAL,time=10.980072021484375
# gamma=0.08,status:OPTIMAL,time=8.057744026184082
# ******* Time for iter 14: 359.28 seconds *********
# Oracle: status = OPTIMAL,time=1.2013580799102783
# ETO: status = OPTIMAL,time=18.587852001190186
# gamma=0.0,status:OPTIMAL,time=33.86153197288513
# gamma=0.005,status:OPTIMAL,time=31.489430904388428
# gamma=0.01,status:OPTIMAL,time=31.795523166656494
# gamma=0.015,status:OPTIMAL,time=27.341570138931274
# gamma=0.02,status:OPTIMAL,time=25.474196910858154
# gamma=0.03,status:OPTIMAL,time=26.806905031204224
# gamma=0.04,status:OPTIMAL,time=19.533370971679688
# gamma=0.06,status:OPTIMAL,time=19.347995042800903
# gamma=0.08,status:OPTIMAL,time=13.308354139328003
# ******* Time for iter 15: 284.79 seconds *********
# Oracle: status = OPTIMAL,time=1.767091989517212
# ETO: status = OPTIMAL,time=20.15704083442688
# gamma=0.0,status:OPTIMAL,time=17.618958950042725
# gamma=0.005,status:OPTIMAL,time=23.696582794189453
# gamma=0.01,status:OPTIMAL,time=25.075129985809326
# gamma=0.015,status:OPTIMAL,time=25.55608081817627
# gamma=0.02,status:OPTIMAL,time=22.900799036026
# gamma=0.03,status:OPTIMAL,time=23.863384008407593
# gamma=0.04,status:OPTIMAL,time=18.133471965789795
# gamma=0.06,status:OPTIMAL,time=18.196616172790527
# gamma=0.08,status:OPTIMAL,time=16.1423978805542
# ******* Time for iter 16: 230.92 seconds *********
# Oracle: status = OPTIMAL,time=1.7994990348815918
# ETO: status = OPTIMAL,time=6.224161148071289
# gamma=0.0,status:OPTIMAL,time=49.144912004470825
# gamma=0.005,status:OPTIMAL,time=44.01474714279175
# gamma=0.01,status:OPTIMAL,time=44.41140103340149
# gamma=0.015,status:OPTIMAL,time=40.66549491882324
# gamma=0.02,status:OPTIMAL,time=31.186455011367798
# gamma=0.03,status:OPTIMAL,time=35.34025597572327
# gamma=0.04,status:OPTIMAL,time=43.68993592262268
# gamma=0.06,status:OPTIMAL,time=39.542060136795044
# gamma=0.08,status:OPTIMAL,time=39.97197914123535
# ******* Time for iter 17: 425.33 seconds *********
# Oracle: status = OPTIMAL,time=1.9787349700927734
# ETO: status = OPTIMAL,time=7.890366792678833
# gamma=0.0,status:OPTIMAL,time=36.40817308425903
# gamma=0.005,status:OPTIMAL,time=38.91790008544922
# gamma=0.01,status:OPTIMAL,time=39.00659990310669
# gamma=0.015,status:OPTIMAL,time=27.837275981903076
# gamma=0.02,status:OPTIMAL,time=35.27409291267395
# gamma=0.03,status:OPTIMAL,time=30.226210832595825
# gamma=0.04,status:OPTIMAL,time=26.91184377670288
# gamma=0.06,status:OPTIMAL,time=16.651111841201782
# gamma=0.08,status:OPTIMAL,time=17.731086015701294
# ******* Time for iter 18: 315.47 seconds *********
# Oracle: status = OPTIMAL,time=3.3647029399871826
# ETO: status = OPTIMAL,time=7.45210599899292
# gamma=0.0,status:OPTIMAL,time=29.712316036224365
# gamma=0.005,status:OPTIMAL,time=43.35609412193298
# gamma=0.01,status:OPTIMAL,time=45.542272090911865
# gamma=0.015,status:OPTIMAL,time=27.583882093429565
# gamma=0.02,status:OPTIMAL,time=32.75958204269409
# gamma=0.03,status:OPTIMAL,time=22.369980096817017
# gamma=0.04,status:OPTIMAL,time=22.794835805892944
# gamma=0.06,status:OPTIMAL,time=13.420686960220337
# gamma=0.08,status:OPTIMAL,time=11.798686027526855
# ******* Time for iter 19: 292.68 seconds *********
# Oracle: status = OPTIMAL,time=1.6182949542999268
# ETO: status = OPTIMAL,time=4.466852903366089
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.6156790256500244
# ETO: status = OPTIMAL,time=4.974124908447266
# gamma=0.0,status:OPTIMAL,time=32.88222098350525
# gamma=0.005,status:OPTIMAL,time=33.04299998283386
# gamma=0.01,status:OPTIMAL,time=31.526644945144653
# gamma=0.015,status:OPTIMAL,time=31.89453887939453
# gamma=0.02,status:OPTIMAL,time=34.23312211036682
# gamma=0.03,status:OPTIMAL,time=44.604764223098755
# gamma=0.04,status:OPTIMAL,time=28.497654914855957
# gamma=0.06,status:OPTIMAL,time=30.134643077850342
# gamma=0.08,status:OPTIMAL,time=24.21078610420227
# ******* Time for iter 20: 332.84 seconds *********
# Oracle: status = OPTIMAL,time=3.0812900066375732
# ETO: status = OPTIMAL,time=6.663561105728149
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.9457108974456787
# ETO: status = OPTIMAL,time=8.551145076751709
# gamma=0.0,status:OPTIMAL,time=20.053986072540283
# gamma=0.005,status:OPTIMAL,time=20.12989902496338
# gamma=0.01,status:OPTIMAL,time=20.294365167617798
# gamma=0.015,status:OPTIMAL,time=20.708157062530518
# gamma=0.02,status:OPTIMAL,time=17.648255109786987
# gamma=0.03,status:OPTIMAL,time=17.371304988861084
# gamma=0.04,status:OPTIMAL,time=19.260797023773193
# gamma=0.06,status:OPTIMAL,time=17.68769097328186
# gamma=0.08,status:OPTIMAL,time=10.769336938858032
# ******* Time for iter 21: 194.67 seconds *********
# Oracle: status = OPTIMAL,time=2.8299849033355713
# ETO: status = OPTIMAL,time=5.876060962677002
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.6029698848724365
# ETO: status = OPTIMAL,time=2.518890857696533
# gamma=0.0,status:OPTIMAL,time=6.691299915313721
# gamma=0.005,status:OPTIMAL,time=9.384244918823242
# gamma=0.01,status:OPTIMAL,time=10.54274606704712
# gamma=0.015,status:OPTIMAL,time=12.493749141693115
# gamma=0.02,status:OPTIMAL,time=16.644298791885376
# gamma=0.03,status:OPTIMAL,time=35.49985909461975
# gamma=0.04,status:OPTIMAL,time=28.07801914215088
# gamma=0.06,status:OPTIMAL,time=8.8595609664917
# gamma=0.08,status:OPTIMAL,time=12.321441173553467
# ******* Time for iter 22: 152.65 seconds *********
# Oracle: status = OPTIMAL,time=3.1916370391845703
# ETO: status = OPTIMAL,time=9.202708005905151
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.106248140335083
# ETO: status = OPTIMAL,time=20.30904197692871
# gamma=0.0,status:OPTIMAL,time=25.293418169021606
# gamma=0.005,status:OPTIMAL,time=31.212138175964355
# gamma=0.01,status:OPTIMAL,time=18.498543977737427
# gamma=0.015,status:OPTIMAL,time=25.72493004798889
# gamma=0.02,status:OPTIMAL,time=26.00816798210144
# gamma=0.03,status:OPTIMAL,time=20.601552963256836
# gamma=0.04,status:OPTIMAL,time=13.398957967758179
# gamma=0.06,status:OPTIMAL,time=14.76943588256836
# gamma=0.08,status:OPTIMAL,time=15.864105939865112
# ******* Time for iter 23: 238.52 seconds *********
# Oracle: status = OPTIMAL,time=2.0382730960845947
# ETO: status = OPTIMAL,time=7.466602087020874
# gamma=0.0,status:OPTIMAL,time=30.322571992874146
# gamma=0.005,status:OPTIMAL,time=33.19396114349365
# gamma=0.01,status:OPTIMAL,time=32.71058702468872
# gamma=0.015,status:OPTIMAL,time=28.06446099281311
# gamma=0.02,status:OPTIMAL,time=31.453944206237793
# gamma=0.03,status:OPTIMAL,time=30.761182069778442
# gamma=0.04,status:OPTIMAL,time=27.135707139968872
# gamma=0.06,status:OPTIMAL,time=16.755000114440918
# gamma=0.08,status:OPTIMAL,time=14.335166931152344
# ******* Time for iter 24: 284.92 seconds *********
# Oracle: status = OPTIMAL,time=0.992379903793335
# ETO: status = OPTIMAL,time=9.037111043930054
# gamma=0.0,status:OPTIMAL,time=5.807543992996216
# gamma=0.005,status:OPTIMAL,time=7.183670997619629
# gamma=0.01,status:OPTIMAL,time=8.636893033981323
# gamma=0.015,status:OPTIMAL,time=12.283830165863037
# gamma=0.02,status:OPTIMAL,time=23.722754955291748
# gamma=0.03,status:OPTIMAL,time=40.64487910270691
# gamma=0.04,status:OPTIMAL,time=41.53807187080383
# gamma=0.06,status:OPTIMAL,time=37.9302499294281
# gamma=0.08,status:OPTIMAL,time=25.147423028945923
# ******* Time for iter 25: 219.02 seconds *********
# Oracle: status = OPTIMAL,time=1.5296189785003662
# ETO: status = OPTIMAL,time=4.309680938720703
# gamma=0.0,status:OPTIMAL,time=18.454415798187256
# gamma=0.005,status:OPTIMAL,time=18.5749831199646
# gamma=0.01,status:OPTIMAL,time=21.86023187637329
# gamma=0.015,status:OPTIMAL,time=21.197724103927612
# gamma=0.02,status:OPTIMAL,time=21.288195848464966
# gamma=0.03,status:OPTIMAL,time=22.607125997543335
# gamma=0.04,status:OPTIMAL,time=21.16783905029297
# gamma=0.06,status:OPTIMAL,time=16.736816883087158
# gamma=0.08,status:OPTIMAL,time=14.848278999328613
# ******* Time for iter 26: 201.5 seconds *********
# Oracle: status = OPTIMAL,time=1.6886379718780518
# ETO: status = OPTIMAL,time=5.136286973953247
# ETO rev is not equivalent to RO rev
# Estimate contains NaN values
# Oracle: status = OPTIMAL,time=3.1112968921661377
# ETO: status = OPTIMAL,time=6.642770051956177
# gamma=0.0,status:OPTIMAL,time=30.366664171218872
# gamma=0.005,status:OPTIMAL,time=28.95792007446289
# gamma=0.01,status:OPTIMAL,time=20.365499019622803
# gamma=0.015,status:OPTIMAL,time=20.953088998794556
# gamma=0.02,status:OPTIMAL,time=20.008985996246338
# gamma=0.03,status:OPTIMAL,time=19.215310096740723
# gamma=0.04,status:OPTIMAL,time=19.339359045028687
# gamma=0.06,status:OPTIMAL,time=14.913063049316406
# gamma=0.08,status:OPTIMAL,time=13.32891297340393
# ******* Time for iter 27: 227.74 seconds *********
# Oracle: status = OPTIMAL,time=1.4867970943450928
# ETO: status = OPTIMAL,time=5.491147041320801
# gamma=0.0,status:OPTIMAL,time=16.35627508163452
# gamma=0.005,status:OPTIMAL,time=18.860142946243286
# gamma=0.01,status:OPTIMAL,time=19.860389947891235
# gamma=0.015,status:OPTIMAL,time=23.336599111557007
# gamma=0.02,status:OPTIMAL,time=19.09421992301941
# gamma=0.03,status:OPTIMAL,time=15.718318939208984
# gamma=0.04,status:OPTIMAL,time=24.556063175201416
# gamma=0.06,status:OPTIMAL,time=26.555792093276978
# gamma=0.08,status:OPTIMAL,time=21.554024934768677
# ******* Time for iter 28: 210.4 seconds *********
# Oracle: status = OPTIMAL,time=2.8408658504486084
# ETO: status = OPTIMAL,time=10.844629049301147
# gamma=0.0,status:OPTIMAL,time=35.42316699028015
# gamma=0.005,status:OPTIMAL,time=37.075549840927124
# gamma=0.01,status:OPTIMAL,time=23.251216888427734
# gamma=0.015,status:OPTIMAL,time=26.849456071853638
# gamma=0.02,status:OPTIMAL,time=25.668034076690674
# gamma=0.03,status:OPTIMAL,time=24.265365839004517
# gamma=0.04,status:OPTIMAL,time=22.032122135162354
# gamma=0.06,status:OPTIMAL,time=16.962788105010986
# gamma=0.08,status:OPTIMAL,time=12.293745994567871
# ******* Time for iter 29: 272.02 seconds *********
# Oracle: status = OPTIMAL,time=1.4542269706726074
# ETO: status = OPTIMAL,time=3.9107980728149414
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.7913219928741455
# ETO: status = OPTIMAL,time=7.2588419914245605
# gamma=0.0,status:OPTIMAL,time=56.93025016784668
# gamma=0.005,status:OPTIMAL,time=66.52692604064941
# gamma=0.01,status:OPTIMAL,time=74.43104100227356
# gamma=0.015,status:OPTIMAL,time=69.20233607292175
# gamma=0.02,status:OPTIMAL,time=60.31217098236084
# gamma=0.03,status:OPTIMAL,time=59.0040488243103
# gamma=0.04,status:OPTIMAL,time=48.96024489402771
# gamma=0.06,status:OPTIMAL,time=35.85444712638855
# gamma=0.08,status:OPTIMAL,time=36.45541787147522
# ******* Time for iter 30: 573.49 seconds *********
# Oracle: status = OPTIMAL,time=2.828091859817505
# ETO: status = OPTIMAL,time=20.370893955230713
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.9385669231414795
# ETO: status = OPTIMAL,time=3.880882978439331
# gamma=0.0,status:OPTIMAL,time=19.387700080871582
# gamma=0.005,status:OPTIMAL,time=27.438054084777832
# gamma=0.01,status:OPTIMAL,time=21.71772599220276
# gamma=0.015,status:OPTIMAL,time=27.513463973999023
# gamma=0.02,status:OPTIMAL,time=25.101957082748413
# gamma=0.03,status:OPTIMAL,time=29.331669092178345
# gamma=0.04,status:OPTIMAL,time=34.41520404815674
# gamma=0.06,status:OPTIMAL,time=31.031625032424927
# gamma=0.08,status:OPTIMAL,time=26.444452047348022
# ******* Time for iter 31: 268.09 seconds *********
# Oracle: status = OPTIMAL,time=1.4713327884674072
# ETO: status = OPTIMAL,time=25.334870100021362
# gamma=0.0,status:OPTIMAL,time=29.680359840393066
# gamma=0.005,status:OPTIMAL,time=34.19165802001953
# gamma=0.01,status:OPTIMAL,time=37.343536138534546
# gamma=0.015,status:OPTIMAL,time=53.27181315422058
# gamma=0.02,status:OPTIMAL,time=31.887918949127197
# gamma=0.03,status:OPTIMAL,time=45.14602589607239
# gamma=0.04,status:OPTIMAL,time=18.446390867233276
# gamma=0.06,status:OPTIMAL,time=22.131277084350586
# gamma=0.08,status:OPTIMAL,time=16.78778886795044
# ******* Time for iter 32: 345.59 seconds *********
# Oracle: status = OPTIMAL,time=1.8946270942687988
# ETO: status = OPTIMAL,time=13.645195960998535
# gamma=0.0,status:OPTIMAL,time=33.65716290473938
# gamma=0.005,status:OPTIMAL,time=33.713340044021606
# gamma=0.01,status:OPTIMAL,time=35.18292808532715
# gamma=0.015,status:OPTIMAL,time=35.85075497627258
# gamma=0.02,status:OPTIMAL,time=36.665531158447266
# gamma=0.03,status:OPTIMAL,time=28.950740098953247
# gamma=0.04,status:OPTIMAL,time=42.09040379524231
# gamma=0.06,status:OPTIMAL,time=29.300645112991333
# gamma=0.08,status:OPTIMAL,time=25.67780303955078
# ******* Time for iter 33: 352.72 seconds *********
# Oracle: status = OPTIMAL,time=3.194598913192749
# ETO: status = OPTIMAL,time=13.126312017440796
# gamma=0.0,status:OPTIMAL,time=22.160284996032715
# gamma=0.005,status:OPTIMAL,time=38.06005311012268
# gamma=0.01,status:OPTIMAL,time=25.135951042175293
# gamma=0.015,status:OPTIMAL,time=29.4129478931427
# gamma=0.02,status:OPTIMAL,time=26.856502056121826
# gamma=0.03,status:OPTIMAL,time=29.946298122406006
# gamma=0.04,status:OPTIMAL,time=38.57149791717529
# gamma=0.06,status:OPTIMAL,time=37.47642993927002
# gamma=0.08,status:OPTIMAL,time=34.58642506599426
# ******* Time for iter 34: 320.99 seconds *********
# Oracle: status = OPTIMAL,time=1.3425140380859375
# ETO: status = OPTIMAL,time=2.049668073654175
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.6432888507843018
# ETO: status = OPTIMAL,time=4.281819105148315
# gamma=0.0,status:OPTIMAL,time=5.3944549560546875
# gamma=0.005,status:OPTIMAL,time=6.864343166351318
# gamma=0.01,status:OPTIMAL,time=6.516957998275757
# gamma=0.015,status:OPTIMAL,time=6.587010860443115
# gamma=0.02,status:OPTIMAL,time=6.767271041870117
# gamma=0.03,status:OPTIMAL,time=10.052855968475342
# gamma=0.04,status:OPTIMAL,time=16.21850609779358
# gamma=0.06,status:OPTIMAL,time=12.91843295097351
# gamma=0.08,status:OPTIMAL,time=21.36026692390442
# ******* Time for iter 35: 104.2 seconds *********
# Oracle: status = OPTIMAL,time=1.9154798984527588
# ETO: status = OPTIMAL,time=7.736677885055542
# gamma=0.0,status:OPTIMAL,time=18.919872045516968
# gamma=0.005,status:OPTIMAL,time=19.91212511062622
# gamma=0.01,status:OPTIMAL,time=19.024803161621094
# gamma=0.015,status:OPTIMAL,time=18.253084897994995
# gamma=0.02,status:OPTIMAL,time=18.75849485397339
# gamma=0.03,status:OPTIMAL,time=19.666436910629272
# gamma=0.04,status:OPTIMAL,time=19.918746948242188
# gamma=0.06,status:OPTIMAL,time=19.370037078857422
# gamma=0.08,status:OPTIMAL,time=17.901960849761963
# ******* Time for iter 36: 200.34 seconds *********
# Oracle: status = OPTIMAL,time=3.22104811668396
# ETO: status = OPTIMAL,time=22.970810890197754
# gamma=0.0,status:OPTIMAL,time=42.431828022003174
# gamma=0.005,status:OPTIMAL,time=50.683775901794434
# gamma=0.01,status:OPTIMAL,time=50.2337589263916
# gamma=0.015,status:OPTIMAL,time=49.38346600532532
# gamma=0.02,status:OPTIMAL,time=44.84230589866638
# gamma=0.03,status:OPTIMAL,time=43.658721923828125
# gamma=0.04,status:OPTIMAL,time=37.67004108428955
# gamma=0.06,status:OPTIMAL,time=20.856307983398438
# gamma=0.08,status:OPTIMAL,time=17.5140118598938
# ******* Time for iter 37: 425.53 seconds *********
# Oracle: status = OPTIMAL,time=1.6046581268310547
# ETO: status = OPTIMAL,time=7.94328498840332
# gamma=0.0,status:OPTIMAL,time=42.188045024871826
# gamma=0.005,status:OPTIMAL,time=36.19371294975281
# gamma=0.01,status:OPTIMAL,time=35.81491684913635
# gamma=0.015,status:OPTIMAL,time=32.53893995285034
# gamma=0.02,status:OPTIMAL,time=28.04092001914978
# gamma=0.03,status:OPTIMAL,time=28.715755939483643
# gamma=0.04,status:OPTIMAL,time=21.142791986465454
# gamma=0.06,status:OPTIMAL,time=21.008327960968018
# gamma=0.08,status:OPTIMAL,time=13.677319049835205
# ******* Time for iter 38: 310.97 seconds *********
# Oracle: status = OPTIMAL,time=1.3317170143127441
# ETO: status = OPTIMAL,time=4.5786659717559814
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.554955005645752
# ETO: status = OPTIMAL,time=3.2443161010742188
# gamma=0.0,status:OPTIMAL,time=22.426952123641968
# gamma=0.005,status:OPTIMAL,time=22.589651107788086
# gamma=0.01,status:OPTIMAL,time=20.262944221496582
# gamma=0.015,status:OPTIMAL,time=30.263899087905884
# gamma=0.02,status:OPTIMAL,time=33.43276000022888
# gamma=0.03,status:OPTIMAL,time=42.498408794403076
# gamma=0.04,status:OPTIMAL,time=46.05570602416992
# gamma=0.06,status:OPTIMAL,time=37.08694791793823
# gamma=0.08,status:OPTIMAL,time=24.670907020568848
# ******* Time for iter 39: 308.08 seconds *********
# Oracle: status = OPTIMAL,time=2.5674729347229004
# ETO: status = OPTIMAL,time=22.546512126922607
# gamma=0.0,status:OPTIMAL,time=19.88227605819702
# gamma=0.005,status:OPTIMAL,time=25.323886156082153
# gamma=0.01,status:OPTIMAL,time=29.551208019256592
# gamma=0.015,status:OPTIMAL,time=33.34351181983948
# gamma=0.02,status:OPTIMAL,time=57.68170404434204
# gamma=0.03,status:OPTIMAL,time=69.09250593185425
# gamma=0.04,status:OPTIMAL,time=52.86078906059265
# gamma=0.06,status:OPTIMAL,time=34.96858286857605
# gamma=0.08,status:OPTIMAL,time=38.07122588157654
# ******* Time for iter 40: 405.5 seconds *********
# Oracle: status = OPTIMAL,time=3.033078193664551
# ETO: status = OPTIMAL,time=3.5749740600585938
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.6789419651031494
# ETO: status = OPTIMAL,time=2.9362049102783203
# gamma=0.0,status:OPTIMAL,time=53.3571400642395
# gamma=0.005,status:OPTIMAL,time=62.62734293937683
# gamma=0.01,status:OPTIMAL,time=53.96750593185425
# gamma=0.015,status:OPTIMAL,time=51.07055401802063
# gamma=0.02,status:OPTIMAL,time=69.31847095489502
# gamma=0.03,status:OPTIMAL,time=69.03205513954163
# gamma=0.04,status:OPTIMAL,time=51.841346979141235
# gamma=0.06,status:OPTIMAL,time=19.026378870010376
# gamma=0.08,status:OPTIMAL,time=22.403334140777588
# ******* Time for iter 41: 510.28 seconds *********
# Oracle: status = OPTIMAL,time=2.5569839477539062
# ETO: status = OPTIMAL,time=8.366248846054077
# gamma=0.0,status:OPTIMAL,time=67.02609205245972
# gamma=0.005,status:OPTIMAL,time=49.879859924316406
# gamma=0.01,status:OPTIMAL,time=57.540592193603516
# gamma=0.015,status:OPTIMAL,time=36.09415793418884
# gamma=0.02,status:OPTIMAL,time=39.98963904380798
# gamma=0.03,status:OPTIMAL,time=103.19861721992493
# gamma=0.04,status:OPTIMAL,time=35.797642946243286
# gamma=0.06,status:OPTIMAL,time=11.58961796760559
# gamma=0.08,status:OPTIMAL,time=11.089962005615234
# ******* Time for iter 42: 490.92 seconds *********
# Oracle: status = OPTIMAL,time=1.4729018211364746
# ETO: status = OPTIMAL,time=10.89097809791565
# gamma=0.0,status:OPTIMAL,time=32.2246150970459
# gamma=0.005,status:OPTIMAL,time=27.949356079101562
# gamma=0.01,status:OPTIMAL,time=28.16079092025757
# gamma=0.015,status:OPTIMAL,time=30.461573123931885
# gamma=0.02,status:OPTIMAL,time=43.748783111572266
# gamma=0.03,status:OPTIMAL,time=45.231420040130615
# gamma=0.04,status:OPTIMAL,time=41.99790000915527
# gamma=0.06,status:OPTIMAL,time=24.644426107406616
# gamma=0.08,status:OPTIMAL,time=19.34399700164795
# ******* Time for iter 43: 338.56 seconds *********
# Oracle: status = OPTIMAL,time=1.5815739631652832
# ETO: status = OPTIMAL,time=14.193801879882812
# gamma=0.0,status:OPTIMAL,time=25.254349946975708
# gamma=0.005,status:OPTIMAL,time=38.45877504348755
# gamma=0.01,status:OPTIMAL,time=32.436914920806885
# gamma=0.015,status:OPTIMAL,time=27.978221893310547
# gamma=0.02,status:OPTIMAL,time=29.658211946487427
# gamma=0.03,status:OPTIMAL,time=30.585733890533447
# gamma=0.04,status:OPTIMAL,time=35.830971002578735
# gamma=0.06,status:OPTIMAL,time=22.71016812324524
# gamma=0.08,status:OPTIMAL,time=25.575679063796997
# ******* Time for iter 44: 310.63 seconds *********
# Oracle: status = OPTIMAL,time=1.8701739311218262
# ETO: status = OPTIMAL,time=8.098116159439087
# gamma=0.0,status:OPTIMAL,time=30.54402995109558
# gamma=0.005,status:OPTIMAL,time=30.63859486579895
# gamma=0.01,status:OPTIMAL,time=22.507457971572876
# gamma=0.015,status:OPTIMAL,time=26.872066020965576
# gamma=0.02,status:OPTIMAL,time=20.614734888076782
# gamma=0.03,status:OPTIMAL,time=19.955127954483032
# gamma=0.04,status:OPTIMAL,time=18.675177097320557
# gamma=0.06,status:OPTIMAL,time=16.91589379310608
# gamma=0.08,status:OPTIMAL,time=14.516597032546997
# ******* Time for iter 45: 242.05 seconds *********
# Oracle: status = OPTIMAL,time=1.7371599674224854
# ETO: status = OPTIMAL,time=4.6629111766815186
# gamma=0.0,status:OPTIMAL,time=11.850454092025757
# gamma=0.005,status:OPTIMAL,time=13.862918853759766
# gamma=0.01,status:OPTIMAL,time=14.550003051757812
# gamma=0.015,status:OPTIMAL,time=13.054914951324463
# gamma=0.02,status:OPTIMAL,time=13.755453824996948
# gamma=0.03,status:OPTIMAL,time=17.569880962371826
# gamma=0.04,status:OPTIMAL,time=28.900205850601196
# gamma=0.06,status:OPTIMAL,time=31.781670093536377
# gamma=0.08,status:OPTIMAL,time=18.964091062545776
# ******* Time for iter 46: 183.22 seconds *********
# Oracle: status = OPTIMAL,time=2.075784921646118
# ETO: status = OPTIMAL,time=18.188117027282715
# gamma=0.0,status:OPTIMAL,time=46.12168097496033
# gamma=0.005,status:OPTIMAL,time=49.739059925079346
# gamma=0.01,status:OPTIMAL,time=48.24697709083557
# gamma=0.015,status:OPTIMAL,time=38.60464310646057
# gamma=0.02,status:OPTIMAL,time=48.057056188583374
# gamma=0.03,status:OPTIMAL,time=35.82494783401489
# gamma=0.04,status:OPTIMAL,time=36.740391969680786
# gamma=0.06,status:OPTIMAL,time=24.700413942337036
# gamma=0.08,status:OPTIMAL,time=15.247002124786377
# ******* Time for iter 47: 409.12 seconds *********
# Oracle: status = OPTIMAL,time=1.3771758079528809
# ETO: status = OPTIMAL,time=5.0610270500183105
# gamma=0.0,status:OPTIMAL,time=34.10823106765747
# gamma=0.005,status:OPTIMAL,time=26.304301977157593
# gamma=0.01,status:OPTIMAL,time=58.14894104003906
# gamma=0.015,status:OPTIMAL,time=39.91334295272827
# gamma=0.02,status:OPTIMAL,time=60.97460603713989
# gamma=0.03,status:OPTIMAL,time=71.01507711410522
# gamma=0.04,status:OPTIMAL,time=103.73335099220276
# gamma=0.06,status:OPTIMAL,time=61.88153290748596
# gamma=0.08,status:OPTIMAL,time=72.8344841003418
# ******* Time for iter 48: 569.32 seconds *********
# Oracle: status = OPTIMAL,time=1.8727631568908691
# ETO: status = OPTIMAL,time=16.29065489768982
# gamma=0.0,status:OPTIMAL,time=57.48260283470154
# gamma=0.005,status:OPTIMAL,time=46.96904897689819
# gamma=0.01,status:OPTIMAL,time=35.5243718624115
# gamma=0.015,status:OPTIMAL,time=54.35312604904175
# gamma=0.02,status:OPTIMAL,time=51.786166191101074
# gamma=0.03,status:OPTIMAL,time=56.566673040390015
# gamma=0.04,status:OPTIMAL,time=23.982388973236084
# gamma=0.06,status:OPTIMAL,time=26.19442892074585
# gamma=0.08,status:OPTIMAL,time=28.11350703239441
# ******* Time for iter 49: 460.99 seconds *********
# Oracle: status = OPTIMAL,time=1.7507350444793701
# ETO: status = OPTIMAL,time=11.538644075393677
# gamma=0.0,status:OPTIMAL,time=26.2866530418396
# gamma=0.005,status:OPTIMAL,time=34.344671964645386
# gamma=0.01,status:OPTIMAL,time=52.15047311782837
# gamma=0.015,status:OPTIMAL,time=26.270445108413696
# gamma=0.02,status:OPTIMAL,time=24.230722904205322
# gamma=0.03,status:OPTIMAL,time=21.593652963638306
# gamma=0.04,status:OPTIMAL,time=18.65984797477722
# gamma=0.06,status:OPTIMAL,time=23.387591123580933
# gamma=0.08,status:OPTIMAL,time=12.261926889419556
# ******* Time for iter 50: 279.24 seconds *********
# Oracle: status = OPTIMAL,time=3.3533449172973633
# ETO: status = OPTIMAL,time=8.481382131576538
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.9697201251983643
# ETO: status = OPTIMAL,time=2.5427889823913574
# gamma=0.0,status:OPTIMAL,time=2.870310068130493
# gamma=0.005,status:OPTIMAL,time=3.0598368644714355
# gamma=0.01,status:OPTIMAL,time=3.5753819942474365
# gamma=0.015,status:OPTIMAL,time=3.7102198600769043
# gamma=0.02,status:OPTIMAL,time=4.372306823730469
# gamma=0.03,status:OPTIMAL,time=3.2253332138061523
# gamma=0.04,status:OPTIMAL,time=6.188068866729736
# gamma=0.06,status:OPTIMAL,time=22.714617013931274
# gamma=0.08,status:OPTIMAL,time=12.532862901687622
# ******* Time for iter 51: 69.89 seconds *********
# Oracle: status = OPTIMAL,time=3.1526589393615723
# ETO: status = OPTIMAL,time=12.317959070205688
# gamma=0.0,status:OPTIMAL,time=34.67198419570923
# gamma=0.005,status:OPTIMAL,time=38.748992919921875
# gamma=0.01,status:OPTIMAL,time=40.73295307159424
# gamma=0.015,status:OPTIMAL,time=63.231608867645264
# gamma=0.02,status:OPTIMAL,time=65.25729393959045
# gamma=0.03,status:OPTIMAL,time=59.99901008605957
# gamma=0.04,status:OPTIMAL,time=57.85478401184082
# gamma=0.06,status:OPTIMAL,time=27.290220022201538
# gamma=0.08,status:OPTIMAL,time=26.84646511077881
# ******* Time for iter 52: 464.89 seconds *********
# Oracle: status = OPTIMAL,time=1.5495610237121582
# ETO: status = OPTIMAL,time=5.046351909637451
# gamma=0.0,status:OPTIMAL,time=11.17530608177185
# gamma=0.005,status:OPTIMAL,time=10.73761510848999
# gamma=0.01,status:OPTIMAL,time=15.102927207946777
# gamma=0.015,status:OPTIMAL,time=18.189953088760376
# gamma=0.02,status:OPTIMAL,time=19.836715936660767
# gamma=0.03,status:OPTIMAL,time=35.65947604179382
# gamma=0.04,status:OPTIMAL,time=42.39597797393799
# gamma=0.06,status:OPTIMAL,time=38.11539697647095
# gamma=0.08,status:OPTIMAL,time=28.89325189590454
# ******* Time for iter 53: 238.24 seconds *********
# Estimate contains NaN values
# Estimate contains NaN values
# Oracle: status = OPTIMAL,time=1.7410321235656738
# ETO: status = OPTIMAL,time=9.699365854263306
# gamma=0.0,status:OPTIMAL,time=45.87808704376221
# gamma=0.005,status:OPTIMAL,time=43.1723530292511
# gamma=0.01,status:OPTIMAL,time=38.78575301170349
# gamma=0.015,status:OPTIMAL,time=38.57392597198486
# gamma=0.02,status:OPTIMAL,time=34.38229203224182
# gamma=0.03,status:OPTIMAL,time=23.301934957504272
# gamma=0.04,status:OPTIMAL,time=25.160259008407593
# gamma=0.06,status:OPTIMAL,time=19.47163701057434
# gamma=0.08,status:OPTIMAL,time=15.323974132537842
# ******* Time for iter 54: 342.18 seconds *********
# Oracle: status = OPTIMAL,time=1.7604401111602783
# ETO: status = OPTIMAL,time=1.8878469467163086
# gamma=0.0,status:OPTIMAL,time=15.402208805084229
# gamma=0.005,status:OPTIMAL,time=22.07662582397461
# gamma=0.01,status:OPTIMAL,time=24.353245973587036
# gamma=0.015,status:OPTIMAL,time=24.895735025405884
# gamma=0.02,status:OPTIMAL,time=29.20345902442932
# gamma=0.03,status:OPTIMAL,time=26.119093894958496
# gamma=0.04,status:OPTIMAL,time=37.60880708694458
# gamma=0.06,status:OPTIMAL,time=41.18462300300598
# gamma=0.08,status:OPTIMAL,time=26.80296492576599
# ******* Time for iter 55: 267.3 seconds *********
# Oracle: status = OPTIMAL,time=2.797401189804077
# ETO: status = OPTIMAL,time=3.8047690391540527
# gamma=0.0,status:OPTIMAL,time=14.117847919464111
# gamma=0.005,status:OPTIMAL,time=15.890836000442505
# gamma=0.01,status:OPTIMAL,time=21.601364135742188
# gamma=0.015,status:OPTIMAL,time=41.63040590286255
# gamma=0.02,status:OPTIMAL,time=58.29895997047424
# gamma=0.03,status:OPTIMAL,time=63.296457052230835
# gamma=0.04,status:OPTIMAL,time=62.20295286178589
# gamma=0.06,status:OPTIMAL,time=66.67371320724487
# gamma=0.08,status:OPTIMAL,time=24.054193019866943
# ******* Time for iter 56: 388.74 seconds *********
# Oracle: status = OPTIMAL,time=2.267529010772705
# ETO: status = OPTIMAL,time=6.687067031860352
# gamma=0.0,status:OPTIMAL,time=34.9424569606781
# gamma=0.005,status:OPTIMAL,time=40.986674070358276
# gamma=0.01,status:OPTIMAL,time=34.93292284011841
# gamma=0.015,status:OPTIMAL,time=32.180938959121704
# gamma=0.02,status:OPTIMAL,time=28.091398000717163
# gamma=0.03,status:OPTIMAL,time=26.600669145584106
# gamma=0.04,status:OPTIMAL,time=24.082528114318848
# gamma=0.06,status:OPTIMAL,time=18.78612995147705
# gamma=0.08,status:OPTIMAL,time=16.669420957565308
# ******* Time for iter 57: 301.74 seconds *********
# Oracle: status = OPTIMAL,time=3.6125009059906006
# ETO: status = OPTIMAL,time=8.343852996826172
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.6595799922943115
# ETO: status = OPTIMAL,time=10.535936117172241
# gamma=0.0,status:OPTIMAL,time=9.774299144744873
# gamma=0.005,status:OPTIMAL,time=12.1857430934906
# gamma=0.01,status:OPTIMAL,time=11.388495206832886
# gamma=0.015,status:OPTIMAL,time=11.794826984405518
# gamma=0.02,status:OPTIMAL,time=14.663321018218994
# gamma=0.03,status:OPTIMAL,time=12.524433851242065
# gamma=0.04,status:OPTIMAL,time=16.657342195510864
# gamma=0.06,status:OPTIMAL,time=16.27536702156067
# gamma=0.08,status:OPTIMAL,time=21.14974880218506
# ******* Time for iter 58: 148.48 seconds *********
# Oracle: status = OPTIMAL,time=2.424220085144043
# ETO: status = OPTIMAL,time=4.304243087768555
# gamma=0.0,status:OPTIMAL,time=9.264647006988525
# gamma=0.005,status:OPTIMAL,time=9.959977865219116
# gamma=0.01,status:OPTIMAL,time=10.044278860092163
# gamma=0.015,status:OPTIMAL,time=12.208764791488647
# gamma=0.02,status:OPTIMAL,time=12.705996990203857
# gamma=0.03,status:OPTIMAL,time=22.119559049606323
# gamma=0.04,status:OPTIMAL,time=22.907033920288086
# gamma=0.06,status:OPTIMAL,time=52.41841101646423
# gamma=0.08,status:OPTIMAL,time=49.47449493408203
# ******* Time for iter 59: 217.11 seconds *********
# Oracle: status = OPTIMAL,time=3.127448797225952
# ETO: status = OPTIMAL,time=11.56335711479187
# gamma=0.0,status:OPTIMAL,time=26.384485960006714
# gamma=0.005,status:OPTIMAL,time=29.66129493713379
# gamma=0.01,status:OPTIMAL,time=34.63061499595642
# gamma=0.015,status:OPTIMAL,time=35.793668031692505
# gamma=0.02,status:OPTIMAL,time=20.87260413169861
# gamma=0.03,status:OPTIMAL,time=24.193817138671875
# gamma=0.04,status:OPTIMAL,time=21.113460063934326
# gamma=0.06,status:OPTIMAL,time=19.48740816116333
# gamma=0.08,status:OPTIMAL,time=18.76195788383484
# ******* Time for iter 60: 272.45 seconds *********
# Oracle: status = OPTIMAL,time=3.176156997680664
# ETO: status = OPTIMAL,time=20.410634994506836
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=3.07840895652771
# ETO: status = OPTIMAL,time=4.482177019119263
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.442531108856201
# ETO: status = OPTIMAL,time=14.664954900741577
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.990849018096924
# ETO: status = OPTIMAL,time=3.348500967025757
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.7796928882598877
# ETO: status = OPTIMAL,time=8.704848051071167
# gamma=0.0,status:OPTIMAL,time=6.1509621143341064
# gamma=0.005,status:OPTIMAL,time=6.6283299922943115
# gamma=0.01,status:OPTIMAL,time=7.1761109828948975
# gamma=0.015,status:OPTIMAL,time=9.466650009155273
# gamma=0.02,status:OPTIMAL,time=13.850361824035645
# gamma=0.03,status:OPTIMAL,time=21.928237915039062
# gamma=0.04,status:OPTIMAL,time=42.12845492362976
# gamma=0.06,status:OPTIMAL,time=52.776554107666016
# gamma=0.08,status:OPTIMAL,time=42.62288999557495
# ******* Time for iter 61: 219.66 seconds *********
# Oracle: status = OPTIMAL,time=2.6224560737609863
# ETO: status = OPTIMAL,time=9.862846851348877
# gamma=0.0,status:OPTIMAL,time=54.62479901313782
# gamma=0.005,status:OPTIMAL,time=38.67474889755249
# gamma=0.01,status:OPTIMAL,time=40.12229800224304
# gamma=0.015,status:OPTIMAL,time=39.407066106796265
# gamma=0.02,status:OPTIMAL,time=36.97295594215393
# gamma=0.03,status:OPTIMAL,time=27.26721692085266
# gamma=0.04,status:OPTIMAL,time=32.31182599067688
# gamma=0.06,status:OPTIMAL,time=16.436387062072754
# gamma=0.08,status:OPTIMAL,time=14.022388935089111
# ******* Time for iter 62: 367.05 seconds *********
# Oracle: status = OPTIMAL,time=1.9694640636444092
# ETO: status = OPTIMAL,time=23.331573963165283
# gamma=0.0,status:OPTIMAL,time=33.9980309009552
# gamma=0.005,status:OPTIMAL,time=34.1629581451416
# gamma=0.01,status:OPTIMAL,time=32.23717021942139
# gamma=0.015,status:OPTIMAL,time=28.118507862091064
# gamma=0.02,status:OPTIMAL,time=26.14013910293579
# gamma=0.03,status:OPTIMAL,time=23.003094911575317
# gamma=0.04,status:OPTIMAL,time=21.52169418334961
# gamma=0.06,status:OPTIMAL,time=26.5070481300354
# gamma=0.08,status:OPTIMAL,time=24.47263503074646
# ******* Time for iter 63: 309.08 seconds *********
# Oracle: status = OPTIMAL,time=1.3576529026031494
# ETO: status = OPTIMAL,time=2.4392809867858887
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.0064258575439453
# ETO: status = OPTIMAL,time=16.373364210128784
# gamma=0.0,status:OPTIMAL,time=46.261638164520264
# gamma=0.005,status:OPTIMAL,time=29.28752303123474
# gamma=0.01,status:OPTIMAL,time=25.787928104400635
# gamma=0.015,status:OPTIMAL,time=28.996896982192993
# gamma=0.02,status:OPTIMAL,time=27.71416711807251
# gamma=0.03,status:OPTIMAL,time=20.362133979797363
# gamma=0.04,status:OPTIMAL,time=18.72923707962036
# gamma=0.06,status:OPTIMAL,time=17.236865997314453
# gamma=0.08,status:OPTIMAL,time=13.589730024337769
# ******* Time for iter 64: 293.47 seconds *********
# Oracle: status = OPTIMAL,time=2.0811378955841064
# ETO: status = OPTIMAL,time=13.652080059051514
# gamma=0.0,status:OPTIMAL,time=62.77671790122986
# gamma=0.005,status:OPTIMAL,time=55.52564597129822
# gamma=0.01,status:OPTIMAL,time=52.98566508293152
# gamma=0.015,status:OPTIMAL,time=50.38158917427063
# gamma=0.02,status:OPTIMAL,time=49.98072910308838
# gamma=0.03,status:OPTIMAL,time=41.074146032333374
# gamma=0.04,status:OPTIMAL,time=44.344748973846436
# gamma=0.06,status:OPTIMAL,time=23.5318341255188
# gamma=0.08,status:OPTIMAL,time=22.578723907470703
# ******* Time for iter 65: 482.52 seconds *********
# Oracle: status = OPTIMAL,time=1.5388660430908203
# ETO: status = OPTIMAL,time=7.6268699169158936
# gamma=0.0,status:OPTIMAL,time=39.55758500099182
# gamma=0.005,status:OPTIMAL,time=56.13824796676636
# gamma=0.01,status:OPTIMAL,time=49.34639501571655
# gamma=0.015,status:OPTIMAL,time=45.3318829536438
# gamma=0.02,status:OPTIMAL,time=40.10703992843628
# gamma=0.03,status:OPTIMAL,time=50.312516927719116
# gamma=0.04,status:OPTIMAL,time=39.121086835861206
# gamma=0.06,status:OPTIMAL,time=21.965996026992798
# gamma=0.08,status:OPTIMAL,time=24.863529920578003
# ******* Time for iter 66: 419.02 seconds *********
# Oracle: status = OPTIMAL,time=2.0903899669647217
# ETO: status = OPTIMAL,time=9.061398029327393
# gamma=0.0,status:OPTIMAL,time=24.70731806755066
# gamma=0.005,status:OPTIMAL,time=21.62319302558899
# gamma=0.01,status:OPTIMAL,time=31.8437180519104
# gamma=0.015,status:OPTIMAL,time=38.326555013656616
# gamma=0.02,status:OPTIMAL,time=21.93180799484253
# gamma=0.03,status:OPTIMAL,time=30.85597014427185
# gamma=0.04,status:OPTIMAL,time=21.42839479446411
# gamma=0.06,status:OPTIMAL,time=25.403203010559082
# gamma=0.08,status:OPTIMAL,time=25.82499885559082
# ******* Time for iter 67: 278.18 seconds *********
# Oracle: status = OPTIMAL,time=1.7694339752197266
# ETO: status = OPTIMAL,time=19.169450998306274
# gamma=0.0,status:OPTIMAL,time=32.83135390281677
# gamma=0.005,status:OPTIMAL,time=42.40249705314636
# gamma=0.01,status:OPTIMAL,time=35.06852889060974
# gamma=0.015,status:OPTIMAL,time=37.48460412025452
# gamma=0.02,status:OPTIMAL,time=38.22461700439453
# gamma=0.03,status:OPTIMAL,time=33.725520849227905
# gamma=0.04,status:OPTIMAL,time=30.1959011554718
# gamma=0.06,status:OPTIMAL,time=24.084316968917847
# gamma=0.08,status:OPTIMAL,time=17.24503993988037
# ******* Time for iter 68: 345.27 seconds *********
# Oracle: status = OPTIMAL,time=2.528218984603882
# ETO: status = OPTIMAL,time=9.518918991088867
# gamma=0.0,status:OPTIMAL,time=28.319025993347168
# gamma=0.005,status:OPTIMAL,time=25.995566844940186
# gamma=0.01,status:OPTIMAL,time=24.47732901573181
# gamma=0.015,status:OPTIMAL,time=17.814634084701538
# gamma=0.02,status:OPTIMAL,time=19.423207998275757
# gamma=0.03,status:OPTIMAL,time=19.76320195198059
# gamma=0.04,status:OPTIMAL,time=20.316887140274048
# gamma=0.06,status:OPTIMAL,time=17.55330204963684
# gamma=0.08,status:OPTIMAL,time=17.710705995559692
# ******* Time for iter 69: 232.2 seconds *********
# Oracle: status = OPTIMAL,time=1.8072528839111328
# ETO: status = OPTIMAL,time=13.649446964263916
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.6491649150848389
# ETO: status = OPTIMAL,time=7.7479259967803955
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.059725046157837
# ETO: status = OPTIMAL,time=3.8882761001586914
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.5480320453643799
# ETO: status = OPTIMAL,time=6.554311037063599
# gamma=0.0,status:OPTIMAL,time=14.290372133255005
# gamma=0.005,status:OPTIMAL,time=15.140666961669922
# gamma=0.01,status:OPTIMAL,time=15.24482798576355
# gamma=0.015,status:OPTIMAL,time=19.098896980285645
# gamma=0.02,status:OPTIMAL,time=14.076007843017578
# gamma=0.03,status:OPTIMAL,time=10.304868936538696
# gamma=0.04,status:OPTIMAL,time=9.273828029632568
# gamma=0.06,status:OPTIMAL,time=11.115236043930054
# gamma=0.08,status:OPTIMAL,time=10.431911945343018
# ******* Time for iter 70: 141.45 seconds *********
# Oracle: status = OPTIMAL,time=1.8685100078582764
# ETO: status = OPTIMAL,time=5.753030061721802
# gamma=0.0,status:OPTIMAL,time=17.868772983551025
# gamma=0.005,status:OPTIMAL,time=14.802095890045166
# gamma=0.01,status:OPTIMAL,time=16.57880401611328
# gamma=0.015,status:OPTIMAL,time=15.851855993270874
# gamma=0.02,status:OPTIMAL,time=8.77848196029663
# gamma=0.03,status:OPTIMAL,time=10.451855897903442
# gamma=0.04,status:OPTIMAL,time=12.221055030822754
# gamma=0.06,status:OPTIMAL,time=7.671399116516113
# gamma=0.08,status:OPTIMAL,time=11.230280876159668
# ******* Time for iter 71: 140.71 seconds *********
# Oracle: status = OPTIMAL,time=1.6168179512023926
# ETO: status = OPTIMAL,time=15.501727104187012
# gamma=0.0,status:OPTIMAL,time=20.686347007751465
# gamma=0.005,status:OPTIMAL,time=22.764708042144775
# gamma=0.01,status:OPTIMAL,time=19.131425142288208
# gamma=0.015,status:OPTIMAL,time=19.35160493850708
# gamma=0.02,status:OPTIMAL,time=18.010195016860962
# gamma=0.03,status:OPTIMAL,time=14.825106143951416
# gamma=0.04,status:OPTIMAL,time=13.439170837402344
# gamma=0.06,status:OPTIMAL,time=11.383572101593018
# gamma=0.08,status:OPTIMAL,time=11.658354043960571
# ******* Time for iter 72: 189.51 seconds *********
# Oracle: status = OPTIMAL,time=1.7855300903320312
# ETO: status = OPTIMAL,time=2.8739850521087646
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.28688907623291
# ETO: status = OPTIMAL,time=9.351603984832764
# gamma=0.0,status:OPTIMAL,time=29.029453992843628
# gamma=0.005,status:OPTIMAL,time=32.9227991104126
# gamma=0.01,status:OPTIMAL,time=42.91092801094055
# gamma=0.015,status:OPTIMAL,time=58.658282995224
# gamma=0.02,status:OPTIMAL,time=39.310643911361694
# gamma=0.03,status:OPTIMAL,time=55.38701415061951
# gamma=0.04,status:OPTIMAL,time=36.64859485626221
# gamma=0.06,status:OPTIMAL,time=51.407317876815796
# gamma=0.08,status:OPTIMAL,time=41.79119086265564
# ******* Time for iter 73: 428.74 seconds *********
# Oracle: status = OPTIMAL,time=1.8918418884277344
# ETO: status = OPTIMAL,time=6.722437858581543
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.789424180984497
# ETO: status = OPTIMAL,time=19.63140296936035
# gamma=0.0,status:OPTIMAL,time=16.208168983459473
# gamma=0.005,status:OPTIMAL,time=19.09791898727417
# gamma=0.01,status:OPTIMAL,time=19.017833948135376
# gamma=0.015,status:OPTIMAL,time=20.621572971343994
# gamma=0.02,status:OPTIMAL,time=21.17092990875244
# gamma=0.03,status:OPTIMAL,time=24.924758911132812
# gamma=0.04,status:OPTIMAL,time=27.830872058868408
# gamma=0.06,status:OPTIMAL,time=26.94866394996643
# gamma=0.08,status:OPTIMAL,time=18.035959005355835
# ******* Time for iter 74: 232.11 seconds *********
# Oracle: status = OPTIMAL,time=1.5981130599975586
# ETO: status = OPTIMAL,time=5.56581711769104
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.041424036026001
# ETO: status = OPTIMAL,time=8.950023889541626
# ...
# gamma=0.0,status:OPTIMAL,time=32.77977895736694
# gamma=0.005,status:OPTIMAL,time=27.624216079711914
# gamma=0.01,status:OPTIMAL,time=28.23680591583252
# gamma=0.015,status:OPTIMAL,time=25.816032886505127
# gamma=0.02,status:OPTIMAL,time=23.783621072769165
# gamma=0.03,status:OPTIMAL,time=19.71138596534729
# gamma=0.04,status:OPTIMAL,time=20.288172960281372
# gamma=0.06,status:OPTIMAL,time=20.09860110282898
# gamma=0.08,status:OPTIMAL,time=17.102993965148926
# ******* Time for iter 76: 264.9 seconds *********
# Oracle: status = OPTIMAL,time=2.0234341621398926
# ETO: status = OPTIMAL,time=15.450125932693481
# gamma=0.0,status:OPTIMAL,time=22.82725501060486
# gamma=0.005,status:OPTIMAL,time=19.10329508781433
# gamma=0.01,status:OPTIMAL,time=29.33982014656067
# gamma=0.015,status:OPTIMAL,time=28.532315015792847
# gamma=0.02,status:OPTIMAL,time=25.340722799301147
# gamma=0.03,status:OPTIMAL,time=27.7051100730896
# gamma=0.04,status:OPTIMAL,time=22.133928060531616
# gamma=0.06,status:OPTIMAL,time=12.571554899215698
# gamma=0.08,status:OPTIMAL,time=15.39657998085022
# ******* Time for iter 77: 243.47 seconds *********
# Oracle: status = OPTIMAL,time=2.640300989151001
# ETO: status = OPTIMAL,time=4.055041074752808
# gamma=0.0,status:OPTIMAL,time=36.76156210899353
# gamma=0.005,status:OPTIMAL,time=40.97962498664856
# gamma=0.01,status:OPTIMAL,time=38.14152479171753
# gamma=0.015,status:OPTIMAL,time=37.096221923828125
# gamma=0.02,status:OPTIMAL,time=57.03473091125488
# gamma=0.03,status:OPTIMAL,time=34.21049213409424
# gamma=0.04,status:OPTIMAL,time=27.133480072021484
# gamma=0.06,status:OPTIMAL,time=26.920289993286133
# gamma=0.08,status:OPTIMAL,time=14.714387893676758
# ******* Time for iter 78: 357.11 seconds *********
# Oracle: status = OPTIMAL,time=2.9653191566467285
# ETO: status = OPTIMAL,time=5.232005834579468
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.4384231567382812
# ETO: status = OPTIMAL,time=11.032289981842041
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.3845820426940918
# ETO: status = OPTIMAL,time=8.469707012176514
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.606130838394165
# ETO: status = OPTIMAL,time=20.602406978607178
# gamma=0.0,status:OPTIMAL,time=18.067972898483276
# gamma=0.005,status:OPTIMAL,time=20.709917068481445
# gamma=0.01,status:OPTIMAL,time=22.034975051879883
# gamma=0.015,status:OPTIMAL,time=17.912811040878296
# gamma=0.02,status:OPTIMAL,time=17.13513493537903
# gamma=0.03,status:OPTIMAL,time=23.16442108154297
# gamma=0.04,status:OPTIMAL,time=21.87977910041809
# gamma=0.06,status:OPTIMAL,time=20.890047073364258
# gamma=0.08,status:OPTIMAL,time=19.107852935791016
# ******* Time for iter 79: 221.65 seconds *********
# Oracle: status = OPTIMAL,time=2.1067399978637695
# ETO: status = OPTIMAL,time=5.5156261920928955
# gamma=0.0,status:OPTIMAL,time=50.43167495727539
# gamma=0.005,status:OPTIMAL,time=45.20832085609436
# gamma=0.01,status:OPTIMAL,time=43.29418897628784
# gamma=0.015,status:OPTIMAL,time=52.29951095581055
# gamma=0.02,status:OPTIMAL,time=39.45554208755493
# gamma=0.03,status:OPTIMAL,time=40.4193480014801
# gamma=0.04,status:OPTIMAL,time=37.777374029159546
# gamma=0.06,status:OPTIMAL,time=21.384232997894287
# gamma=0.08,status:OPTIMAL,time=15.55322003364563
# ******* Time for iter 80: 403.55 seconds *********
# Oracle: status = OPTIMAL,time=1.3310678005218506
# ETO: status = OPTIMAL,time=18.885244131088257
# gamma=0.0,status:OPTIMAL,time=34.67103910446167
# gamma=0.005,status:OPTIMAL,time=59.489901065826416
# gamma=0.01,status:OPTIMAL,time=53.41530704498291
# gamma=0.015,status:OPTIMAL,time=69.57664799690247
# gamma=0.02,status:OPTIMAL,time=46.32990598678589
# gamma=0.03,status:OPTIMAL,time=65.651780128479
# gamma=0.04,status:OPTIMAL,time=54.25898003578186
# gamma=0.06,status:OPTIMAL,time=45.64945578575134
# gamma=0.08,status:OPTIMAL,time=25.29234290122986
# ******* Time for iter 81: 509.25 seconds *********
# Oracle: status = OPTIMAL,time=1.4630348682403564
# ETO: status = OPTIMAL,time=11.236763954162598
# gamma=0.0,status:OPTIMAL,time=26.072503805160522
# gamma=0.005,status:OPTIMAL,time=24.714271068572998
# gamma=0.01,status:OPTIMAL,time=26.5134539604187
# gamma=0.015,status:OPTIMAL,time=25.099751949310303
# gamma=0.02,status:OPTIMAL,time=23.37552499771118
# gamma=0.03,status:OPTIMAL,time=28.222180128097534
# gamma=0.04,status:OPTIMAL,time=29.03869390487671
# gamma=0.06,status:OPTIMAL,time=22.990641117095947
# gamma=0.08,status:OPTIMAL,time=21.3563551902771
# ******* Time for iter 82: 266.63 seconds *********
# Oracle: status = OPTIMAL,time=3.0925180912017822
# ETO: status = OPTIMAL,time=4.502060890197754
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.8731679916381836
# ETO: status = OPTIMAL,time=9.805340051651001
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=3.711503028869629
# ETO: status = OPTIMAL,time=5.781368017196655
# gamma=0.0,status:OPTIMAL,time=17.14776587486267
# gamma=0.005,status:OPTIMAL,time=18.63465714454651
# gamma=0.01,status:OPTIMAL,time=17.606112957000732
# gamma=0.015,status:OPTIMAL,time=22.14594793319702
# gamma=0.02,status:OPTIMAL,time=18.685091972351074
# gamma=0.03,status:OPTIMAL,time=24.77451992034912
# gamma=0.04,status:OPTIMAL,time=22.270956993103027
# gamma=0.06,status:OPTIMAL,time=20.263500928878784
# gamma=0.08,status:OPTIMAL,time=15.27745008468628
# ******* Time for iter 83: 203.75 seconds *********
# Oracle: status = OPTIMAL,time=1.548551082611084
# ETO: status = OPTIMAL,time=5.598790168762207
# gamma=0.0,status:OPTIMAL,time=30.072926998138428
# gamma=0.005,status:OPTIMAL,time=44.92740082740784
# gamma=0.01,status:OPTIMAL,time=38.900320053100586
# gamma=0.015,status:OPTIMAL,time=39.99395990371704
# gamma=0.02,status:OPTIMAL,time=33.469659090042114
# gamma=0.03,status:OPTIMAL,time=30.841198921203613
# gamma=0.04,status:OPTIMAL,time=22.69941210746765
# gamma=0.06,status:OPTIMAL,time=25.854986906051636
# gamma=0.08,status:OPTIMAL,time=23.963053941726685
# ******* Time for iter 84: 328.33 seconds *********
# Oracle: status = OPTIMAL,time=2.8338639736175537
# ETO: status = OPTIMAL,time=5.834375858306885
# gamma=0.0,status:OPTIMAL,time=16.51241707801819
# gamma=0.005,status:OPTIMAL,time=18.70229697227478
# gamma=0.01,status:OPTIMAL,time=21.3279070854187
# gamma=0.015,status:OPTIMAL,time=22.590590953826904
# gamma=0.02,status:OPTIMAL,time=22.317590951919556
# gamma=0.03,status:OPTIMAL,time=23.792465925216675
# gamma=0.04,status:OPTIMAL,time=19.681551933288574
# gamma=0.06,status:OPTIMAL,time=16.724282026290894
# gamma=0.08,status:OPTIMAL,time=9.779546022415161
# ******* Time for iter 85: 196.9 seconds *********
# Oracle: status = OPTIMAL,time=1.2842130661010742
# ETO: status = OPTIMAL,time=2.7197070121765137
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.7649450302124023
# ETO: status = OPTIMAL,time=10.012816190719604
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=1.5111150741577148
# ETO: status = OPTIMAL,time=11.855093955993652
# gamma=0.0,status:OPTIMAL,time=33.36901092529297
# gamma=0.005,status:OPTIMAL,time=37.97957515716553
# gamma=0.01,status:OPTIMAL,time=34.8434419631958
# gamma=0.015,status:OPTIMAL,time=35.59653377532959
# gamma=0.02,status:OPTIMAL,time=33.538002014160156
# gamma=0.03,status:OPTIMAL,time=53.550878047943115
# gamma=0.04,status:OPTIMAL,time=33.80268597602844
# gamma=0.06,status:OPTIMAL,time=34.80153179168701
# gamma=0.08,status:OPTIMAL,time=22.338145971298218
# ******* Time for iter 86: 367.18 seconds *********
# Oracle: status = OPTIMAL,time=1.646209955215454
# ETO: status = OPTIMAL,time=19.798484802246094
# gamma=0.0,status:OPTIMAL,time=24.51781702041626
# gamma=0.005,status:OPTIMAL,time=21.353041172027588
# gamma=0.01,status:OPTIMAL,time=16.56518292427063
# gamma=0.015,status:OPTIMAL,time=26.338441848754883
# gamma=0.02,status:OPTIMAL,time=21.618364095687866
# gamma=0.03,status:OPTIMAL,time=21.696342945098877
# gamma=0.04,status:OPTIMAL,time=23.638044834136963
# gamma=0.06,status:OPTIMAL,time=25.968111038208008
# gamma=0.08,status:OPTIMAL,time=18.1530020236969
# ******* Time for iter 87: 246.43 seconds *********
# Oracle: status = OPTIMAL,time=2.2871251106262207
# ETO: status = OPTIMAL,time=3.9415671825408936
# gamma=0.0,status:OPTIMAL,time=29.17701005935669
# gamma=0.005,status:OPTIMAL,time=32.88267683982849
# gamma=0.01,status:OPTIMAL,time=32.38284993171692
# gamma=0.015,status:OPTIMAL,time=26.817862033843994
# gamma=0.02,status:OPTIMAL,time=30.724300861358643
# gamma=0.03,status:OPTIMAL,time=27.95718812942505
# gamma=0.04,status:OPTIMAL,time=27.249573945999146
# gamma=0.06,status:OPTIMAL,time=30.75079894065857
# gamma=0.08,status:OPTIMAL,time=31.365442037582397
# ******* Time for iter 88: 304.7 seconds *********
# Oracle: status = OPTIMAL,time=2.282526969909668
# ETO: status = OPTIMAL,time=23.062954902648926
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.1290791034698486
# ETO: status = OPTIMAL,time=9.940000057220459
# gamma=0.0,status:OPTIMAL,time=37.71953582763672
# gamma=0.005,status:OPTIMAL,time=30.736727952957153
# gamma=0.01,status:OPTIMAL,time=54.20478296279907
# gamma=0.015,status:OPTIMAL,time=27.400614976882935
# gamma=0.02,status:OPTIMAL,time=40.449130058288574
# gamma=0.03,status:OPTIMAL,time=19.25131392478943
# gamma=0.04,status:OPTIMAL,time=21.385905027389526
# gamma=0.06,status:OPTIMAL,time=30.284623861312866
# gamma=0.08,status:OPTIMAL,time=12.006942987442017
# ******* Time for iter 89: 323.79 seconds *********
# Oracle: status = OPTIMAL,time=2.0436131954193115
# ETO: status = OPTIMAL,time=3.9805901050567627
# gamma=0.0,status:OPTIMAL,time=2.5597422122955322
# gamma=0.005,status:OPTIMAL,time=3.121328830718994
# gamma=0.01,status:OPTIMAL,time=2.527719020843506
# gamma=0.015,status:OPTIMAL,time=2.7253429889678955
# gamma=0.02,status:OPTIMAL,time=2.535759925842285
# gamma=0.03,status:OPTIMAL,time=2.836642026901245
# gamma=0.04,status:OPTIMAL,time=3.6764369010925293
# gamma=0.06,status:OPTIMAL,time=16.710937976837158
# gamma=0.08,status:OPTIMAL,time=30.738159894943237
# ******* Time for iter 90: 76.17 seconds *********
# Oracle: status = OPTIMAL,time=1.6528539657592773
# ETO: status = OPTIMAL,time=9.231799125671387
# gamma=0.0,status:OPTIMAL,time=22.14398217201233
# gamma=0.005,status:OPTIMAL,time=26.546844005584717
# gamma=0.01,status:OPTIMAL,time=18.11237621307373
# gamma=0.015,status:OPTIMAL,time=15.944122791290283
# gamma=0.02,status:OPTIMAL,time=17.367894887924194
# gamma=0.03,status:OPTIMAL,time=21.620231866836548
# gamma=0.04,status:OPTIMAL,time=20.7860689163208
# gamma=0.06,status:OPTIMAL,time=31.17857003211975
# gamma=0.08,status:OPTIMAL,time=18.886125087738037
# ******* Time for iter 91: 225.68 seconds *********
# Oracle: status = OPTIMAL,time=2.0037899017333984
# ETO: status = OPTIMAL,time=13.873178005218506
# gamma=0.0,status:OPTIMAL,time=14.859758138656616
# gamma=0.005,status:OPTIMAL,time=18.31250786781311
# gamma=0.01,status:OPTIMAL,time=35.93623995780945
# gamma=0.015,status:OPTIMAL,time=26.956679105758667
# gamma=0.02,status:OPTIMAL,time=49.25260305404663
# gamma=0.03,status:OPTIMAL,time=36.4193069934845
# gamma=0.04,status:OPTIMAL,time=55.60881209373474
# gamma=0.06,status:OPTIMAL,time=51.35004496574402
# gamma=0.08,status:OPTIMAL,time=59.144428968429565
# ******* Time for iter 92: 378.52 seconds *********
# Oracle: status = OPTIMAL,time=1.46616792678833
# ETO: status = OPTIMAL,time=15.95755910873413
# gamma=0.0,status:OPTIMAL,time=27.363492012023926
# gamma=0.005,status:OPTIMAL,time=37.07463717460632
# gamma=0.01,status:OPTIMAL,time=23.31716799736023
# gamma=0.015,status:OPTIMAL,time=26.65912413597107
# gamma=0.02,status:OPTIMAL,time=29.96018385887146
# gamma=0.03,status:OPTIMAL,time=21.320226192474365
# gamma=0.04,status:OPTIMAL,time=25.960824966430664
# gamma=0.06,status:OPTIMAL,time=19.874170064926147
# gamma=0.08,status:OPTIMAL,time=23.836613178253174
# ******* Time for iter 93: 280.65 seconds *********
# Oracle: status = OPTIMAL,time=1.8626511096954346
# ETO: status = OPTIMAL,time=9.121088027954102
# gamma=0.0,status:OPTIMAL,time=32.250635862350464
# gamma=0.005,status:OPTIMAL,time=34.272531032562256
# gamma=0.01,status:OPTIMAL,time=28.439534187316895
# gamma=0.015,status:OPTIMAL,time=24.87959599494934
# gamma=0.02,status:OPTIMAL,time=21.142417907714844
# gamma=0.03,status:OPTIMAL,time=19.61327314376831
# gamma=0.04,status:OPTIMAL,time=17.310642957687378
# gamma=0.06,status:OPTIMAL,time=12.457316875457764
# gamma=0.08,status:OPTIMAL,time=14.709835052490234
# ******* Time for iter 94: 248.53 seconds *********
# Oracle: status = OPTIMAL,time=1.93143892288208
# ETO: status = OPTIMAL,time=2.44520902633667
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=2.060595989227295
# ETO: status = OPTIMAL,time=2.775826930999756
# gamma=0.0,status:OPTIMAL,time=6.634877920150757
# gamma=0.005,status:OPTIMAL,time=6.535955905914307
# gamma=0.01,status:OPTIMAL,time=8.43009901046753
# gamma=0.015,status:OPTIMAL,time=9.061054944992065
# gamma=0.02,status:OPTIMAL,time=12.216609954833984
# gamma=0.03,status:OPTIMAL,time=21.196563005447388
# gamma=0.04,status:OPTIMAL,time=20.24601912498474
# gamma=0.06,status:OPTIMAL,time=16.592622995376587
# gamma=0.08,status:OPTIMAL,time=17.395605087280273
# ******* Time for iter 95: 130.02 seconds *********
# Oracle: status = OPTIMAL,time=3.779682159423828
# ETO: status = OPTIMAL,time=16.25785803794861
# gamma=0.0,status:OPTIMAL,time=28.37777090072632
# gamma=0.005,status:OPTIMAL,time=27.99303388595581
# gamma=0.01,status:OPTIMAL,time=24.141613006591797
# gamma=0.015,status:OPTIMAL,time=17.425189971923828
# gamma=0.02,status:OPTIMAL,time=17.480703115463257
# gamma=0.03,status:OPTIMAL,time=19.593069076538086
# gamma=0.04,status:OPTIMAL,time=16.81709885597229
# gamma=0.06,status:OPTIMAL,time=15.337598085403442
# gamma=0.08,status:OPTIMAL,time=14.689395904541016
# ******* Time for iter 96: 230.28 seconds *********
# Oracle: status = OPTIMAL,time=1.4555749893188477
# ETO: status = OPTIMAL,time=8.114810943603516
# ETO rev is not equivalent to RO rev
# Oracle: status = OPTIMAL,time=4.237277030944824
# ETO: status = OPTIMAL,time=5.299742937088013
# gamma=0.0,status:OPTIMAL,time=27.447868824005127
# gamma=0.005,status:OPTIMAL,time=24.781116008758545
# gamma=0.01,status:OPTIMAL,time=23.26957678794861
# gamma=0.015,status:OPTIMAL,time=26.279600858688354
# gamma=0.02,status:OPTIMAL,time=25.6234450340271
# gamma=0.03,status:OPTIMAL,time=38.380192041397095
# gamma=0.04,status:OPTIMAL,time=28.51919984817505
# gamma=0.06,status:OPTIMAL,time=17.759421825408936
# gamma=0.08,status:OPTIMAL,time=21.96603798866272
# ******* Time for iter 97: 271.47 seconds *********
# Oracle: status = OPTIMAL,time=1.54380202293396
# ETO: status = OPTIMAL,time=9.624813079833984
# gamma=0.0,status:OPTIMAL,time=22.870659112930298
# gamma=0.005,status:OPTIMAL,time=30.604957103729248
# gamma=0.01,status:OPTIMAL,time=37.33516716957092
# gamma=0.015,status:OPTIMAL,time=31.123260021209717
# gamma=0.02,status:OPTIMAL,time=40.36486196517944
# gamma=0.03,status:OPTIMAL,time=35.262036085128784
# gamma=0.04,status:OPTIMAL,time=39.12963914871216
# gamma=0.06,status:OPTIMAL,time=19.717885971069336
# gamma=0.08,status:OPTIMAL,time=19.103549003601074
# ******* Time for iter 98: 309.71 seconds *********
# Oracle: status = OPTIMAL,time=2.8670690059661865
# ETO: status = OPTIMAL,time=9.890256881713867
# gamma=0.0,status:OPTIMAL,time=32.136630058288574
# gamma=0.005,status:OPTIMAL,time=32.23869490623474
# gamma=0.01,status:OPTIMAL,time=29.458486080169678
# gamma=0.015,status:OPTIMAL,time=31.61829400062561
# gamma=0.02,status:OPTIMAL,time=31.032069206237793
# gamma=0.03,status:OPTIMAL,time=34.85544204711914
# gamma=0.04,status:OPTIMAL,time=25.48915696144104
# gamma=0.06,status:OPTIMAL,time=24.623997926712036
# gamma=0.08,status:OPTIMAL,time=21.455565929412842
# ******* Time for iter 99: 309.18 seconds *********
# Oracle: status = OPTIMAL,time=1.610785961151123
# ETO: status = OPTIMAL,time=2.33371901512146
# gamma=0.0,status:OPTIMAL,time=22.66121816635132
# gamma=0.005,status:OPTIMAL,time=20.958791971206665
# gamma=0.01,status:OPTIMAL,time=21.377379894256592
# gamma=0.015,status:OPTIMAL,time=18.55619978904724
# gamma=0.02,status:OPTIMAL,time=23.585794925689697
# gamma=0.03,status:OPTIMAL,time=13.089858055114746
# gamma=0.04,status:OPTIMAL,time=17.408556938171387
# gamma=0.06,status:OPTIMAL,time=24.72210192680359
# gamma=0.08,status:OPTIMAL,time=21.013884782791138
# ******* Time for iter 100: 210.63 seconds *********

# %%
Result_All = load(string(this_data_file, "Result_All_lambda=$(lambda).jld2"));

# %%
iter = 1
RST_RO_iter = Result_All["RST_RO_iter=$(iter)"]
gamma_list = sort([parse(Float64, split(k, "=")[end]) for k in keys(RST_RO_iter) if startswith(k, "Rev_gamma=")])
println("Gamma list: ", gamma_list)
# Out:
# Gamma list: [0.0, 0.005, 0.01, 0.015, 0.02, 0.03, 0.04, 0.06, 0.08]

# %%
Rev_Oracle = [Result_All["RST_Oracle_iter=$(iter)"]["Rev"] for iter in 1:iterations]
Rev_ETO = [Result_All["RST_ETO_iter=$(iter)"]["Rev"] for iter in 1:iterations]
Rev_RO = zeros(iterations,length(gamma_list))
for iter in 1:iterations
    RST_RO = Result_All["RST_RO_iter=$(iter)"]
    for g_index in 1:length(gamma_list)
        gamma = gamma_list[g_index]
        Rev_RO[iter,g_index] = RST_RO["Rev_gamma=$(gamma)"]
    end
end
println("Rev_ETO/Rev_Oracle = ",round.(Rev_ETO./Rev_Oracle,digits=4))
println("Rev_RO/Rev_Oracle = ",round.(Rev_RO[:,1]./Rev_Oracle,digits=4))
println("Rev_ETO/Rev_Oracle = ",mean(Rev_ETO)/mean(Rev_Oracle))
# Out:
# Rev_ETO/Rev_Oracle = [0.9832, 0.7829, 0.9615, 0.945, 0.6559, 0.791, 0.9813, 0.957, 0.9504, 0.9775, 0.6277, 0.7124, 0.7669, 0.8233, 0.9843, 0.9977, 0.7025, 0.561, 0.9892, 0.9744, 0.994, 0.8481, 0.9265, 0.989, 0.8222, 0.986, 0.9632, 0.9485, 0.7273, 0.9489, 0.9652, 0.9666, 0.961, 0.9571, 0.8739, 0.9381, 0.9826, 0.9473, 0.9669, 0.8677, 0.9376, 0.9862, 0.651, 0.895, 0.9661, 0.9364, 0.9272, 0.8382, 0.9407, 0.947, 0.8564, 0.9409, 0.8623, 0.6366, 0.9873, 0.7777, 0.9497, 0.5003, 0.7674, 0.9288, 0.7899, 0.9626, 0.9638, 0.9077, 0.9515, 0.9568, 0.8494, 0.9139, 0.9662, 0.782, 0.9505, 0.4483, 0.8375, 0.9223, 0.8076, 0.9729, 0.9846, 0.9692, 0.9391, 0.9625, 0.9371, 0.9293, 0.8691, 0.9838, 0.8884, 0.8855, 0.9502, 0.9575, 0.8643, 0.7472, 0.573, 0.8289, 0.9101, 0.9668, 0.8171, 0.9461, 0.9253, 0.482, 0.91, 0.9593]
# Rev_RO/Rev_Oracle = [0.9832, 0.7829, 0.9615, 0.945, 0.6559, 0.791, 0.9813, 0.957, 0.9504, 0.9775, 0.6277, 0.7124, 0.7669, 0.8233, 0.9843, 0.9977, 0.7025, 0.561, 0.9892, 0.9744, 0.994, 0.8481, 0.9265, 0.989, 0.8222, 0.986, 0.9632, 0.9485, 0.7273, 0.9489, 0.9652, 0.9666, 0.961, 0.9571, 0.8739, 0.9381, 0.9826, 0.9473, 0.9669, 0.8677, 0.9376, 0.9862, 0.651, 0.895, 0.9661, 0.9364, 0.9272, 0.8382, 0.9407, 0.947, 0.8564, 0.9409, 0.8623, 0.6366, 0.9873, 0.7777, 0.9497, 0.5004, 0.7674, 0.9288, 0.7899, 0.9626, 0.9638, 0.9076, 0.9515, 0.9568, 0.8494, 0.9139, 0.9662, 0.782, 0.9505, 0.4483, 0.8375, 0.9223, 0.8076, 0.9729, 0.9846, 0.9692, 0.9391, 0.9625, 0.9371, 0.9293, 0.8691, 0.9838, 0.8884, 0.8855, 0.9502, 0.9575, 0.8643, 0.7472, 0.573, 0.8289, 0.9101, 0.9668, 0.8171, 0.9461, 0.9253, 0.482, 0.91, 0.9593]
# Rev_ETO/Rev_Oracle = 0.8810513463604549

# %%
RO_ETO_Ratio_Mean = zeros(length(gamma_list))
RO_ETO_Ratio_Std = zeros(length(gamma_list))
for g_index in 1:length(gamma_list)
    gamma = gamma_list[g_index]
    RO_ETO_Ratio_Mean[g_index] = mean(Rev_RO[:,g_index])/mean(Rev_ETO)
    RO_ETO_Ratio_Std[g_index] = std(Rev_RO[:,g_index])/std(Rev_ETO)
    println("gamma=$gamma,Mean =",RO_ETO_Ratio_Mean[g_index],", Std =",RO_ETO_Ratio_Std[g_index])
end
# Out:
# gamma=0.0,Mean =1.00000016133686, Std =0.9999813063543568
# gamma=0.005,Mean =1.009360401047258, Std =0.9555661906788648
# gamma=0.01,Mean =1.0097151756060838, Std =0.9296232473864151
# gamma=0.015,Mean =1.010680591560742, Std =0.9256537438007755
# gamma=0.02,Mean =0.9951799405505491, Std =0.9812455029576549
# gamma=0.03,Mean =0.9678259360337788, Std =0.9672816097631312
# gamma=0.04,Mean =0.921202546143789, Std =0.9709666732169288
# gamma=0.06,Mean =0.8339865978139412, Std =1.0070154249620402
# gamma=0.08,Mean =0.7605840224422562, Std =0.972465188340405

# %%
end_index = length(gamma_list) - 3
plot(gamma_list[1:end_index], RO_ETO_Ratio_Mean[1:end_index], marker=:o, xlabel=L"\gamma", label="Average Profit", xticks=(gamma_list[1:end_index], string.(gamma_list[1:end_index])))
plot!(gamma_list[1:end_index], RO_ETO_Ratio_Std[1:end_index], marker=:o, xlabel=L"\gamma", ylabel="RPD/ETOPD", label="Std of Profit")
hline!([1.0], linestyle=:dash, color=:red, label="")
display(current())
savefig(string(this_data_file, "RPP_vs_ETOPP.pdf"))
# Out:
# "/Users/zhangxun/Dropbox/Research/Robust_Exp/Data/Joint_Pricing_and_Promotion/MS_2024_N=3_N_u=1_K=30_S_train=100_seed=3_ECP_Estimation/RPP_vs_ETOPP.pdf"

# %%
chosen_indices = [1,2,3,4]
gamma_chosen = gamma_list[chosen_indices]
data = [Rev_ETO./mean(Rev_ETO), [Rev_RO[:,ind]./mean(Rev_ETO) for ind in chosen_indices]...]
labels = ["ETO"; ["RO($gamma)" for gamma in gamma_chosen]]
# --- 1) 展开成长表 ---
df = DataFrame(
    value = vcat(data...),
    group = repeat(labels, inner = length(data[1]))
)

mycolors = palette(:tab10)[1:length(labels)]   # tab10 最多10个颜色
mycolors = ["#f47e20","#f59898","#1f78b4","#329f48","#6b3e97","#d2ab82","#f47e20"]
# --- 3) 绘制箱线图 ---
@df df boxplot(:group, :value;
    group = :group,
    palette = mycolors,
    legend = false,
    ylabel = "Normalized Revenue",
    # title = "Revenue Distribution"
)

# --- 4) 计算均值 ---
means = combine(groupby(df, :group), :value => mean => :mean_val)

for i in 1:length(labels)
    scatter!([labels[i]], [means.mean_val[i]];
        color = :red,
        marker = (:star, 10),
        label = "")
end

# # # --- 6) 绘制均值连线（这里必须把类别转为数值 1:N） ---
# plot!(labels, means.mean_val;
#     seriestype = :line,
#     color = :red,
#     lw = 2,
#     ls = :dash,
#     label = "Mean trend"
# )
display(current())
savefig(string(this_data_file, "RPP_vs_ETOPP_BoxPlot.pdf"))
# Out:
# "/Users/zhangxun/Dropbox/Research/Robust_Exp/Data/Joint_Pricing_and_Promotion/MS_2024_N=3_N_u=1_K=30_S_train=100_seed=3_ECP_Estimation/RPP_vs_ETOPP_BoxPlot.pdf"

# %%
# bad_idx = findall(i -> abs(Rev_ETO[i] - Rev_RO[i,1]) > 0.01, 1:length(Rev_ETO));
# keep_idx = setdiff(1:length(Rev_ETO), bad_idx);
# Rev_ETO_clean = Rev_ETO[keep_idx];
# Rev_Oracle_clean = Rev_Oracle[keep_idx];
# Rev_RO_clean = Rev_RO[keep_idx, :];
# RO_ETO_Ratio_Mean = zeros(length(gamma_list))
# RO_ETO_Ratio_Std = zeros(length(gamma_list))
# for g_index in 1:length(gamma_list)
#     gamma = gamma_list[g_index]
#     RO_ETO_Ratio_Mean[g_index] = mean(Rev_RO_clean[:,g_index])/mean(Rev_ETO_clean)
#     RO_ETO_Ratio_Std[g_index] = std(Rev_RO_clean[:,g_index])/std(Rev_ETO_clean)
#     println("gamma=$gamma,Mean =",RO_ETO_Ratio_Mean[g_index],", Std =",RO_ETO_Ratio_Std[g_index])
# end
# println("Rev_ETO/Rev_Oracle = ",mean(Rev_ETO_clean)/mean(Rev_Oracle_clean))

# %%
# end_index = length(gamma_list) -1
# plot(gamma_list[1:end_index], RO_ETO_Ratio_Mean[1:end_index], marker=:o, xlabel=L"\gamma", label="Average Profit", xticks=(gamma_list[1:end_index], string.(gamma_list[1:end_index])))
# plot!(gamma_list[1:end_index], RO_ETO_Ratio_Std[1:end_index], marker=:o, xlabel=L"\gamma", ylabel="RPD/ETOPD", label="Std of Profit")
# hline!([1.0], linestyle=:dash, color=:red, label="")
# display(current())
# savefig(string(this_data_file, "RPP_vs_ETOPP_Clean.pdf"))
